# %% [markdown]
# # 학습 및 검증

# %% [markdown]
# ### 1) 필요한 라이브러리 설치

# %%
import pandas as pd
import os
import re
import json
import yaml
from glob import glob
from tqdm import tqdm
from pprint import pprint
import torch
import pytorch_lightning as pl
from rouge import Rouge # 모델의 성능을 평가하기 위한 라이브러리입니다.
from datetime import datetime

from torch.utils.data import Dataset , DataLoader
from transformers import AutoTokenizer, BartForConditionalGeneration, BartConfig, AutoModelForSeq2SeqLM
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import Trainer, TrainingArguments
from transformers import EarlyStoppingCallback

import wandb # 모델 학습 과정을 손쉽게 Tracking하고, 시각화할 수 있는 라이브러리입니다.

# %% [markdown]
# ### 2) Config file 만들기

# %%
MODEL_NAME = "gogamza/kobart-summarization"
MODEL_NAME_SHORT = "gogamza"
VERSION = "V2"

# config 설정에 tokenizer 모듈이 사용되므로 미리 tokenizer를 정의해줍니다.
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
config_data = {
    "general": {
        "data_path": "../../../../data/processed", # 모델 생성에 필요한 데이터 경로를 사용자 환경에 맞게 지정합니다.
        "model_name": MODEL_NAME, # 불러올 모델의 이름을 사용자 환경에 맞게 지정할 수 있습니다.
        "output_dir": "./" # 모델의 최종 출력 값을 저장할 경로를 설정합니다.
    },
    "tokenizer": {
        "encoder_max_len": 512,
        "decoder_max_len": 128,
        "bos_token": f"{tokenizer.bos_token}",
        "eos_token": f"{tokenizer.eos_token}",
        # 특정 단어들이 분해되어 tokenization이 수행되지 않도록 special_tokens을 지정해줍니다.
        "special_tokens": ['#Person1#', '#Person2#', '#Person3#', '#Person4#', '#Person5#', '#Person6#', '#Person7#',
                           '#PhoneNumber#', '#Address#', '#PassportNumber#']
    },
    "training": {
        "overwrite_output_dir": True,
        "num_train_epochs": 10,
        "learning_rate": 2e-5,
        "per_device_train_batch_size": 16,
        "per_device_eval_batch_size": 16,
        "warmup_ratio": 0.15,
        "weight_decay": 0.01,
        "lr_scheduler_type": 'cosine',
        "optim": 'adamw_torch',
        "gradient_accumulation_steps": 2,
        "evaluation_strategy": 'epoch',
        "save_strategy": 'epoch',
        "save_total_limit": 3,
        "fp16": True,
        "load_best_model_at_end": True,
        "seed": 42,
        "logging_dir": "./logs",
        "logging_strategy": "epoch",
        "predict_with_generate": True,
        "generation_max_length": 80,
        "do_train": True,
        "do_eval": True,
        "early_stopping_patience": 2,
        "early_stopping_threshold": 0.001,
        "report_to": "wandb" # (선택) wandb를 사용할 때 설정합니다.
    },
    # (선택) wandb 홈페이지에 가입하여 얻은 정보를 기반으로 작성합니다.
    "wandb": {
        "entity": "imeanseo_",
        "project": "dialogue-summarization",
        "name": f"{MODEL_NAME}_{VERSION}"
    },
    "inference": {
        "ckt_path": "./checkpoint/", # 사전 학습이 진행된 모델의 checkpoint를 저장할 경로를 설정합니다.
        "result_path": "./prediction/",
        "no_repeat_ngram_size": 3,
        "early_stopping": True,
        "generate_max_length": 80,
        "min_length": 20,  
        "num_beams": 5,
        "batch_size" : 16,
        "remove_tokens": ['<usr>', '<unk>', f"{tokenizer.bos_token}", f"{tokenizer.eos_token}", f"{tokenizer.pad_token}"]
    }
}

# %%
# 모델의 구성 정보를 YAML 파일로 저장합니다.
config_path = f"./config_{MODEL_NAME_SHORT}_{VERSION}.yaml"
with open(config_path, "w") as file:
    yaml.dump(config_data, file, allow_unicode=True)

# %% [markdown]
# ### 3) Configuration 불러오기

# %%
# 저장된 config 파일을 불러옵니다.
with open(config_path, "r") as file:
    loaded_config = yaml.safe_load(file)

# 불러온 config 파일의 전체 내용을 확인합니다.
pprint(loaded_config)
# Out:
# {'general': {'data_path': '../../../../data/processed',
#              'model_name': 'gogamza/kobart-summarization',
#              'output_dir': './'},
#  'inference': {'batch_size': 16,
#                'ckt_path': './checkpoint/',
#                'early_stopping': True,
#                'generate_max_length': 80,
#                'min_length': 20,
#                'no_repeat_ngram_size': 3,
#                'num_beams': 5,
#                'remove_tokens': ['<usr>', '<unk>', '<s>', '</s>', '<pad>'],
#                'result_path': './prediction/'},
#  'tokenizer': {'bos_token': '<s>',
#                'decoder_max_len': 128,
#                'encoder_max_len': 512,
#                'eos_token': '</s>',
#                'special_tokens': ['#Person1#',
#                                   '#Person2#',
#                                   '#Person3#',
#                                   '#Person4#',
#                                   '#Person5#',
#                                   '#Person6#',
#                                   '#Person7#',
#                                   '#PhoneNumber#',
#                                   '#Address#',
#                                   '#PassportNumber#']},
#  'training': {'do_eval': True,
#               'do_train': True,
#               'early_stopping_patience': 2,
#               'early_stopping_threshold': 0.001,
#               'evaluation_strategy': 'epoch',
#               'fp16': True,
#               'generation_max_length': 80,
#               'gradient_accumulation_steps': 2,
#               'learning_rate': 2e-05,
#               'load_best_model_at_end': True,
#               'logging_dir': './logs',
#               'logging_strategy': 'epoch',
#               'lr_scheduler_type': 'cosine',
#               'num_train_epochs': 10,
#               'optim': 'adamw_torch',
#               'overwrite_output_dir': True,
#               'per_device_eval_batch_size': 16,
#               'per_device_train_batch_size': 16,
#               'predict_with_generate': True,
#               'report_to': 'wandb',
#               'save_strategy': 'epoch',
#               'save_total_limit': 3,
#               'seed': 42,
#               'warmup_ratio': 0.15,
#               'weight_decay': 0.01},
#  'wandb': {'entity': 'imeanseo_',
#            'name': 'gogamza/kobart-summarization_V2',
#            'project': 'dialogue-summarization'}}

# %% [markdown]
# ### 4) 전처리 데이터 로드

# %%
# 전처리 데이터 불러오기
data_dir = loaded_config["general"]["data_path"] 
train_data_path = os.path.join(data_dir, "train_preprocessed.csv")
test_data_path = os.path.join(data_dir, "test_preprocessed.csv")
dev_data_path = os.path.join(data_dir, "dev_preprocessed.csv")

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
dev_data = pd.read_csv(dev_data_path)

print(f"✅ 전처리 된 학습 데이터 개수: {len(train_data)}")
print(f"✅ 전처리 된 테스트 데이터 개수: {len(test_data)}")
print(f"✅ 전처리 된 검증 데이터 개수: {len(dev_data)}")
# Out:
# ✅ 전처리 된 학습 데이터 개수: 12457
# ✅ 전처리 된 테스트 데이터 개수: 499
# ✅ 전처리 된 검증 데이터 개수: 499

# %% [markdown]
# ### 5) 데이터셋 클래스 구축

# %% [markdown]
# - 1. 토크나이징 & 데이터셋 클래스

# %%
# Train에 사용되는 Dataset 클래스를 정의합니다.
class DatasetForTrain(Dataset):
    def __init__(self, encoder_input, decoder_input, labels, len):
        self.encoder_input = encoder_input
        self.decoder_input = decoder_input
        self.labels = labels
        self.len = len

    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encoder_input.items()} # item[input_ids], item[attention_mask]
        item2 = {key: val[idx].clone().detach() for key, val in self.decoder_input.items()} # item2[input_ids], item2[attention_mask]
        item2['decoder_input_ids'] = item2['input_ids']
        item2['decoder_attention_mask'] = item2['attention_mask']
        item2.pop('input_ids')
        item2.pop('attention_mask')
        item.update(item2) #item[input_ids], item[attention_mask] item[decoder_input_ids], item[decoder_attention_mask]
        item['labels'] = self.labels['input_ids'][idx] #item[input_ids], item[attention_mask] item[decoder_input_ids], item[decoder_attention_mask], item[labels]
        return item

    def __len__(self):
        return self.len

# Validation에 사용되는 Dataset 클래스를 정의합니다.
class DatasetForVal(Dataset):
    def __init__(self, encoder_input, decoder_input, labels, len):
        self.encoder_input = encoder_input
        self.decoder_input = decoder_input
        self.labels = labels
        self.len = len

    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encoder_input.items()} # item[input_ids], item[attention_mask]
        item2 = {key: val[idx].clone().detach() for key, val in self.decoder_input.items()} # item2[input_ids], item2[attention_mask]
        item2['decoder_input_ids'] = item2['input_ids']
        item2['decoder_attention_mask'] = item2['attention_mask']
        item2.pop('input_ids')
        item2.pop('attention_mask')
        item.update(item2) #item[input_ids], item[attention_mask] item[decoder_input_ids], item[decoder_attention_mask]
        item['labels'] = self.labels['input_ids'][idx] #item[input_ids], item[attention_mask] item[decoder_input_ids], item[decoder_attention_mask], item[labels]
        return item

    def __len__(self):
        return self.len

# Test에 사용되는 Dataset 클래스를 정의합니다.
class DatasetForInference(Dataset):
    def __init__(self, encoder_input, test_id, len):
        self.encoder_input = encoder_input
        self.test_id = test_id
        self.len = len

    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encoder_input.items()}
        item['ID'] = self.test_id[idx]
        return item

    def __len__(self):
        return self.len

# %% [markdown]
# - 2. 데이터셋 전처리 클래스

# %%
# 데이터 전처리를 위한 클래스로, 데이터셋을 데이터프레임으로 변환하고 인코더와 디코더의 입력을 생성합니다.
class Preprocess:
    def __init__(self,
            bos_token: str,
            eos_token: str,
        ) -> None:

        self.bos_token = bos_token
        self.eos_token = eos_token

    @staticmethod
    # 실험에 필요한 컬럼을 가져옵니다.
    def make_set_as_df(file_path, is_train = True):
        if is_train:
            df = pd.read_csv(file_path)
            train_df = df[['fname','dialogue','summary']]
            return train_df
        else:
            df = pd.read_csv(file_path)
            test_df = df[['fname','dialogue']]
            return test_df

    # BART 모델의 입력, 출력 형태를 맞추기 위해 전처리를 진행합니다.
    def make_input(self, dataset,is_test = False):
        if is_test:
            encoder_input = dataset['dialogue']
            decoder_input = [self.bos_token] * len(dataset['dialogue'])
            return encoder_input.tolist(), list(decoder_input)
        else:
            encoder_input = dataset['dialogue']
            decoder_input = dataset['summary'].apply(lambda x : self.bos_token + str(x)) # Ground truth를 디코더의 input으로 사용하여 학습합니다.
            decoder_output = dataset['summary'].apply(lambda x : str(x) + self.eos_token)
            return encoder_input.tolist(), decoder_input.tolist(), decoder_output.tolist()

# %% [markdown]
# - 3. 데이터셋 생성 함수

# %%
# tokenization 과정까지 진행된 최종적으로 모델에 입력될 데이터를 출력합니다.
def prepare_train_dataset(config, preprocessor, data_path, tokenizer):
    train_file_path = os.path.join(data_path,'train_preprocessed.csv')
    val_file_path = os.path.join(data_path,'dev_preprocessed.csv')

    # train, validation에 대해 각각 데이터프레임을 구축합니다.
    train_data = preprocessor.make_set_as_df(train_file_path)
    val_data = preprocessor.make_set_as_df(val_file_path)

    print('-'*150)
    print(f'train_data:\n {train_data["dialogue"][0]}')
    print(f'train_label:\n {train_data["summary"][0]}')

    print('-'*150)
    print(f'val_data:\n {val_data["dialogue"][0]}')
    print(f'val_label:\n {val_data["summary"][0]}')

    encoder_input_train , decoder_input_train, decoder_output_train = preprocessor.make_input(train_data)
    encoder_input_val , decoder_input_val, decoder_output_val = preprocessor.make_input(val_data)
    print('-'*10, 'Load data complete', '-'*10,)

    tokenized_encoder_inputs = tokenizer(encoder_input_train, return_tensors="pt", padding=True,
                            add_special_tokens=True, truncation=True, max_length=config['tokenizer']['encoder_max_len'], return_token_type_ids=False)
    tokenized_decoder_inputs = tokenizer(decoder_input_train, return_tensors="pt", padding=True,
                        add_special_tokens=True, truncation=True, max_length=config['tokenizer']['decoder_max_len'], return_token_type_ids=False)
    tokenized_decoder_ouputs = tokenizer(decoder_output_train, return_tensors="pt", padding=True,
                        add_special_tokens=True, truncation=True, max_length=config['tokenizer']['decoder_max_len'], return_token_type_ids=False)

    train_inputs_dataset = DatasetForTrain(tokenized_encoder_inputs, tokenized_decoder_inputs, tokenized_decoder_ouputs,len(encoder_input_train))

    val_tokenized_encoder_inputs = tokenizer(encoder_input_val, return_tensors="pt", padding=True,
                        add_special_tokens=True, truncation=True, max_length=config['tokenizer']['encoder_max_len'], return_token_type_ids=False)
    val_tokenized_decoder_inputs = tokenizer(decoder_input_val, return_tensors="pt", padding=True,
                        add_special_tokens=True, truncation=True, max_length=config['tokenizer']['decoder_max_len'], return_token_type_ids=False)
    val_tokenized_decoder_ouputs = tokenizer(decoder_output_val, return_tensors="pt", padding=True,
                        add_special_tokens=True, truncation=True, max_length=config['tokenizer']['decoder_max_len'], return_token_type_ids=False)

    val_inputs_dataset = DatasetForVal(val_tokenized_encoder_inputs, val_tokenized_decoder_inputs, val_tokenized_decoder_ouputs,len(encoder_input_val))

    print('-'*10, 'Make dataset complete', '-'*10,)
    return train_inputs_dataset, val_inputs_dataset

# %% [markdown]
# ### 6) 평가 지표 계산 함수 생성

# %%
# 모델 성능에 대한 평가 지표를 정의합니다. 본 대회에서는 ROUGE 점수를 통해 모델의 성능을 평가합니다.
def compute_metrics(config,tokenizer,pred):
    rouge = Rouge()
    predictions = pred.predictions
    labels = pred.label_ids

    predictions[predictions == -100] = tokenizer.pad_token_id
    labels[labels == -100] = tokenizer.pad_token_id

    decoded_preds = tokenizer.batch_decode(predictions, clean_up_tokenization_spaces=True)
    labels = tokenizer.batch_decode(labels, clean_up_tokenization_spaces=True)

    # 정확한 평가를 위해 미리 정의된 불필요한 생성토큰들을 제거합니다.
    replaced_predictions = decoded_preds.copy()
    replaced_labels = labels.copy()
    remove_tokens = config['inference']['remove_tokens']
    for token in remove_tokens:
        replaced_predictions = [sentence.replace(token," ") for sentence in replaced_predictions]
        replaced_labels = [sentence.replace(token," ") for sentence in replaced_labels]

    print('-'*150)
    print(f"PRED: {replaced_predictions[0]}")
    print(f"GOLD: {replaced_labels[0]}")
    print('-'*150)
    print(f"PRED: {replaced_predictions[1]}")
    print(f"GOLD: {replaced_labels[1]}")
    print('-'*150)
    print(f"PRED: {replaced_predictions[2]}")
    print(f"GOLD: {replaced_labels[2]}")

    # 최종적인 ROUGE 점수를 계산합니다.
    results = rouge.get_scores(replaced_predictions, replaced_labels,avg=True)

    # ROUGE 점수 중 F-1 score를 통해 평가합니다.
    result = {key: value["f"] for key, value in results.items()}
    return result

# %% [markdown]
# ### 7) 모델, 토크나이저, 트레이너 로드

# %%
# 학습을 위한 tokenizer와 사전 학습된 모델을 불러옵니다.
def load_tokenizer_and_model_for_train(config,device):
    print('-'*10, 'Load tokenizer & model', '-'*10,)
    print('-'*10, f'Model Name : {config["general"]["model_name"]}', '-'*10,)
    model_name = config['general']['model_name']
    bart_config = BartConfig().from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    generate_model = BartForConditionalGeneration.from_pretrained(config['general']['model_name'],config=bart_config)

    special_tokens_dict={'additional_special_tokens':config['tokenizer']['special_tokens']}
    tokenizer.add_special_tokens(special_tokens_dict)

    generate_model.resize_token_embeddings(len(tokenizer)) # 사전에 special token을 추가했으므로 재구성 해줍니다.
    generate_model.to(device)
    print(generate_model.config)

    print('-'*10, 'Load tokenizer & model complete', '-'*10,)
    return generate_model , tokenizer

# %%
# 학습을 위한 trainer 클래스와 매개변수를 정의합니다.
def load_trainer_for_train(config,generate_model,tokenizer,train_inputs_dataset,val_inputs_dataset):
    print('-'*10, 'Make training arguments', '-'*10,)
    # set training args
    training_args = Seq2SeqTrainingArguments(
                output_dir=config['general']['output_dir'], # model output directory
                overwrite_output_dir=config['training']['overwrite_output_dir'],
                num_train_epochs=config['training']['num_train_epochs'],  # total number of training epochs
                learning_rate=config['training']['learning_rate'], # learning_rate
                per_device_train_batch_size=config['training']['per_device_train_batch_size'], # batch size per device during training
                per_device_eval_batch_size=config['training']['per_device_eval_batch_size'],# batch size for evaluation
                warmup_ratio=config['training']['warmup_ratio'],  # number of warmup steps for learning rate scheduler
                weight_decay=config['training']['weight_decay'],  # strength of weight decay
                lr_scheduler_type=config['training']['lr_scheduler_type'],
                optim =config['training']['optim'],
                gradient_accumulation_steps=config['training']['gradient_accumulation_steps'],
                evaluation_strategy=config['training']['evaluation_strategy'], # evaluation strategy to adopt during training
                save_strategy =config['training']['save_strategy'],
                save_total_limit=config['training']['save_total_limit'], # number of total save model.
                fp16=config['training']['fp16'],
                load_best_model_at_end=config['training']['load_best_model_at_end'], # 최종적으로 가장 높은 점수 저장
                seed=config['training']['seed'],
                logging_dir=config['training']['logging_dir'], # directory for storing logs
                logging_strategy=config['training']['logging_strategy'],
                predict_with_generate=config['training']['predict_with_generate'], #To use BLEU or ROUGE score
                generation_max_length=config['training']['generation_max_length'],
                do_train=config['training']['do_train'],
                do_eval=config['training']['do_eval'],
                report_to=config['training']['report_to'] # (선택) wandb를 사용할 때 설정합니다.
            )

    # (선택) 모델의 학습 과정을 추적하는 wandb를 사용하기 위해 초기화 해줍니다.
    wandb.init(
        entity=config['wandb']['entity'],
        project=config['wandb']['project'],
        name=config['wandb']['name'],
    )

    # (선택) 모델 checkpoint를 wandb에 저장하도록 환경 변수를 설정합니다.
    os.environ["WANDB_LOG_MODEL"]="true"
    os.environ["WANDB_WATCH"]="false"

    # Validation loss가 더 이상 개선되지 않을 때 학습을 중단시키는 EarlyStopping 기능을 사용합니다.
    MyCallback = EarlyStoppingCallback(
        early_stopping_patience=config['training']['early_stopping_patience'],
        early_stopping_threshold=config['training']['early_stopping_threshold']
    )
    print('-'*10, 'Make training arguments complete', '-'*10,)
    print('-'*10, 'Make trainer', '-'*10,)

    # Trainer 클래스를 정의합니다.
    trainer = Seq2SeqTrainer(
        model=generate_model, # 사용자가 사전 학습하기 위해 사용할 모델을 입력합니다.
        args=training_args,
        train_dataset=train_inputs_dataset,
        eval_dataset=val_inputs_dataset,
        compute_metrics = lambda pred: compute_metrics(config,tokenizer, pred),
        callbacks = [MyCallback]
    )
    print('-'*10, 'Make trainer complete', '-'*10,)

    return trainer

# %% [markdown]
# ### 8) 학습 수행

# %%
# checkpoint 디렉토리 설정을 위해 현재 시간을 기반으로 run_name을 자동 생성
now = datetime.now().strftime("%m%d_%H%M")
base_name = loaded_config['wandb']['name']
run_name = f"{base_name}_{now}"
loaded_config['general']['output_dir'] = f"./checkpoint/"

loaded_config['wandb']['name'] = run_name

print(f"🔥 Run Name 자동 생성: {run_name}")
# Out:
# 🔥 Run Name 자동 생성: gogamza/kobart-summarization_V2_1204_1429

# %%
def main(config):
    # 사용할 device를 정의합니다.
    device = torch.device('cuda:0' if torch.cuda.is_available()  else 'cpu')
    print('-'*10, f'device : {device}', '-'*10,)
    print(torch.__version__)

    # 사용할 모델과 tokenizer를 불러옵니다.
    generate_model , tokenizer = load_tokenizer_and_model_for_train(config,device)
    print('-'*10,"tokenizer special tokens : ",tokenizer.special_tokens_map,'-'*10)

    # 학습에 사용할 데이터셋을 불러옵니다.
    preprocessor = Preprocess(config['tokenizer']['bos_token'], config['tokenizer']['eos_token']) # decoder_start_token: str, eos_token: str
    data_path = config['general']['data_path']
    train_inputs_dataset, val_inputs_dataset = prepare_train_dataset(config,preprocessor, data_path, tokenizer)

    # Trainer 클래스를 불러옵니다.
    trainer = load_trainer_for_train(config, generate_model,tokenizer,train_inputs_dataset,val_inputs_dataset)
    
    print("🔥 학습을 시작합니다!")
    trainer.train()   # 모델 학습을 시작합니다.

    # (선택) 모델 학습이 완료된 후 wandb를 종료합니다.
    wandb.finish()

# %%
if __name__ == "__main__":
    main(loaded_config)
# Out:
# ---------- device : cuda:0 ----------
# 2.1.0
# ---------- Load tokenizer & model ----------
# ---------- Model Name : gogamza/kobart-summarization ----------
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# BartConfig {
#   "_name_or_path": "gogamza/kobart-summarization",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 0,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 2,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "transformers_version": "4.35.2",
#   "use_cache": true,
#   "vocab_size": 30010
# }
#
# ---------- Load tokenizer & model complete ----------
# ---------- tokenizer special tokens :  {'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': '<mask>', 'additional_special_tokens': ['#Person5#', '#PassportNumber#', '#Person2#', '#Person7#', '#Address#', '#Person1#', '#Person6#', '#Person3#', '#PhoneNumber#', '#Person4#']} ----------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# train_data:
#  #Person1# 안녕하세요, Mr. Smith. 저는 Dr. Hawkins입니다. 오늘 무슨 일로 오셨어요? #Person2# 건강검진을 받으려고 왔어요. #Person1# 네, 5년 동안 검진을 안 받으셨네요. 매년 한 번씩 받으셔야 해요. #Person2# 알죠. 특별히 아픈 데가 없으면 굳이 갈 필요가 없다고 생각했어요. #Person1# 음, 심각한 질병을 피하려면 미리 발견하는 게 제일 좋거든요. 본인을 위해서라도 매년 한 번은 오세요. #Person2# 알겠습니다. #Person1# 여기 좀 볼까요. 눈과 귀는 괜찮으시네요. 깊게 숨 한 번 쉬어보세요. Mr. Smith, 담배 피우세요? #Person2# 네. #Person1# 담배가 폐암하고 심장병의 주된 원인인 거 아시죠? 끊으셔야 해요. #Person2# 수백 번 시도했는데, 도저히 습관이 안 끊어져요. #Person1# 음, 도움 될만한 수업과 약물들이 있습니다. 가시기 전에 더 정보를 드릴게요. #Person2# 네, 고맙습니다, 의사 선생님.
# train_label:
#  Mr. Smith는 Dr. Hawkins에게 건강검진을 받으러 와서, 매년 검진 필요성을 안내받고 흡연 습관 개선을 위한 도움을 제안받았습니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# val_data:
#  #Person1# 안녕하세요, 오늘 기분이 어떠세요? #Person2# 요즘 숨쉬기가 힘들어요. #Person1# 최근에 감기에 걸렸나요? #Person2# 아니요, 감기는 안 걸렸어요. 숨쉴 때 가슴이 답답해요. #Person1# 혹시 알고 있는 알레르기 있으세요? #Person2# 아니요, 특별히 알고 있는 알레르기는 없어요. #Person1# 이게 항상 그런가요, 아니면 주로 활동할 때 그런가요? #Person2# 운동할 때 특히 많이 그래요. #Person1# 천식 검사를 위해 폐 전문의에게 가보시는 게 좋겠어요. #Person2# 도와주셔서 감사합니다, 의사 선생님.
# val_label:
#  #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ---------- Load data complete ----------
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# ---------- Make dataset complete ----------
# ---------- Make training arguments ----------
# wandb: Currently logged in as: oriori88 (imeanseo_). Use `wandb login --relogin` to force relogin
# wandb version 0.23.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/workspace/dialogue-summarization-nlp-4/code/model/gogamza_kobart-summarization/V2/wandb/run-20251204_142914-jr1aqscq</code>
# Syncing run <strong><a href='https://wandb.ai/imeanseo_/dialogue-summarization/runs/jr1aqscq' target="_blank">gogamza/kobart-summarization_V2_1204_1429</a></strong> to <a href='https://wandb.ai/imeanseo_/dialogue-summarization' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/imeanseo_/dialogue-summarization' target="_blank">https://wandb.ai/imeanseo_/dialogue-summarization</a>
#  View run at <a href='https://wandb.ai/imeanseo_/dialogue-summarization/runs/jr1aqscq' target="_blank">https://wandb.ai/imeanseo_/dialogue-summarization/runs/jr1aqscq</a>
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# ---------- Make training arguments complete ----------
# ---------- Make trainer ----------
# ---------- Make trainer complete ----------
# 🔥 학습을 시작합니다!
#     <div>
#
#       <progress value='2337' max='3890' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2337/3890 13:13 < 08:48, 2.94 it/s, Epoch 6/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge-1</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.763300</td>
#       <td>0.588231</td>
#       <td>0.260581</td>
#       <td>0.052370</td>
#       <td>0.252307</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.391900</td>
#       <td>0.513820</td>
#       <td>0.290091</td>
#       <td>0.073886</td>
#       <td>0.277848</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.319800</td>
#       <td>0.514072</td>
#       <td>0.298147</td>
#       <td>0.080981</td>
#       <td>0.285753</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.293400</td>
#       <td>0.521152</td>
#       <td>0.297935</td>
#       <td>0.084585</td>
#       <td>0.285335</td>
#     </tr>
#   </tbody>
# </table><p>
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 #Person2#에게 알레르기가 있는지 물었습니다. #Person2#는 천식 검사를 위해 폐 전문의에게 가보라고 조언합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  Jimmy는 운동하러 가기로 결정했지만, #Person1#은 주간 일정이 변할 수 있다고 설명한다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 #Person2#에게 요즘 건강에 좋지 않은 음식을 먹지 말라고 조언한다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person2#는 감기에 걸리지 않았지만, 숨쉬는 것이 불편합니다. #Person1#은 #Person2#에게 천식 검사를 위해 폐 전문의에게 가보라고 조언합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  Jimmy는 운동하러 가기로 했습니다. #Person1#은 #Person2#에게 주간 일정에 대해 설명합니다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#과 #Person2#는 건강에 좋지 않은 음식을 먹지 않기로 결정합니다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person2#는 숨쉬기 힘들다고 호소합니다. #Person1#은 #Person2#에게 천식 검사를 위해 폐 전문의에게 가보라고 권유합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 Jimmy에게 운동 날짜를 변경해 달라고 요청하고, Jimmy는 동의한다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#과 건강에 좋지 않은 음식을 먹지 말라고 #Person2#에게 제안합니다. #Person2#는 과일과 채소, 닭고기를 좋아한다고 말합니다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person2#는 숨쉬기 힘들다고 호소합니다. #Person1#은 #Person2#에게 천식 검사를 위해 폐 전문의에게 가보라고 조언합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  Jimmy는 운동 날짜를 바꾸기 위해 #Person1#에게 설득하지만, #Person1#은 주간 일정에 따라 날짜를 변경해야 한다고 답한다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 건강에 좋지 않은 음식을 먹지 말라고 제안하고, #Person2#는 동의합니다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person2#는 숨쉬기 어려움을 호소하며, #Person1#은 천식 검사를 위해 폐 전문의에게 가보라고 권유합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 Jimmy에게 운동 날짜를 바꾸자고 제안하지만, Jimmy는 주간 일정이 있어서 거절한다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 건강에 좋지 않은 음식을 먹지 않으며, #Person2#는 주로 과일과 채소, 닭고기를 먹습니다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person2#는 숨쉬기 어려움을 호소하며, #Person1#은 천식 검사를 위해 폐 전문의에게 가보라고 조언합니다.
# GOLD: #Person2#는 숨쉬기 어려워합니다. 의사는 #Person2#에게 증상을 확인하고, 천식 검사를 위해 폐 전문의에게 가볼 것을 권합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 Jimmy에게 운동 날짜를 바꾸자고 제안하지만, Jimmy는 주간 일정이 있어서 거절한다.
# GOLD: #Person1#는 Jimmy를 운동하러 초대하고 팔과 복근 운동을 하도록 설득합니다.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PRED:  #Person1#은 건강에 좋지 않은 음식을 피하고 싶어 하고, #Person2#는 과일과 채소, 닭고기를 추천한다.
# GOLD: #Person1#은 건강에 안 좋은 음식을 그만 먹기로 결심하고, #Person2#는 자신의 건강한 식단을 #Person1#에게 공유합니다.
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# VBox(children=(Label(value='472.674 MB of 472.674 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▂▁▁▁▂</td></tr><tr><td>eval/rouge-1</td><td>▁▆▆███</td></tr><tr><td>eval/rouge-2</td><td>▁▆▆█▇█</td></tr><tr><td>eval/rouge-l</td><td>▁▆▆█▇▇</td></tr><tr><td>eval/runtime</td><td>▃▁▅█▇▆</td></tr><tr><td>eval/samples_per_second</td><td>▅█▄▁▂▃</td></tr><tr><td>eval/steps_per_second</td><td>▅█▄▁▂▃</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▄▄▅▅▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▄▄▅▅▇▇███</td></tr><tr><td>train/learning_rate</td><td>▄█▇▆▃▁</td></tr><tr><td>train/loss</td><td>█▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.52115</td></tr><tr><td>eval/rouge-1</td><td>0.29793</td></tr><tr><td>eval/rouge-2</td><td>0.08458</td></tr><tr><td>eval/rouge-l</td><td>0.28534</td></tr><tr><td>eval/runtime</td><td>13.5507</td></tr><tr><td>eval/samples_per_second</td><td>36.825</td></tr><tr><td>eval/steps_per_second</td><td>2.361</td></tr><tr><td>train/epoch</td><td>6.0</td></tr><tr><td>train/global_step</td><td>2337</td></tr><tr><td>train/learning_rate</td><td>1e-05</td></tr><tr><td>train/loss</td><td>0.2934</td></tr><tr><td>train/total_flos</td><td>2.278646118088704e+16</td></tr><tr><td>train/train_loss</td><td>0.9286</td></tr><tr><td>train/train_runtime</td><td>790.7116</td></tr><tr><td>train/train_samples_per_second</td><td>157.542</td></tr><tr><td>train/train_steps_per_second</td><td>4.92</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gogamza/kobart-summarization_V2_1204_1429</strong> at: <a href='https://wandb.ai/imeanseo_/dialogue-summarization/runs/jr1aqscq' target="_blank">https://wandb.ai/imeanseo_/dialogue-summarization/runs/jr1aqscq</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251204_142914-jr1aqscq/logs</code>

# %% [markdown]
# # 추론

# %% [markdown]
# ### 1) rouge-l 점수가 가장 높은 체크포인트 찾기

# %%
CHECKPOINT_DIR = loaded_config['inference']['ckt_path']
TARGET_METRIC = "eval_rouge-l"

best_score = -1
best_path = None

for ckpt_name in os.listdir(CHECKPOINT_DIR):
    ckpt_path = os.path.join(CHECKPOINT_DIR, ckpt_name)
    trainer_state_path = os.path.join(ckpt_path, "trainer_state.json")

    if not os.path.isfile(trainer_state_path):
        continue

    # trainer_state.json 읽기
    with open(trainer_state_path, "r") as f:
        state = json.load(f)

    # metrics = 마지막 저장 시점의 평가 점수
    metrics = state.get("log_history", [])
    
    # log_history 중 evaluation 항목만 추출
    for m in metrics:
        if TARGET_METRIC in m:
            score = m[TARGET_METRIC]
            
            if score > best_score:
                best_score = score
                best_path = ckpt_path

print("Best checkpoint:", best_path)
print("Best ROUGE score:", best_score)
# Out:
# Best checkpoint: ./checkpoint/checkpoint-2337
# Best ROUGE score: 0.28901765474109387

# %% [markdown]
# ### 2) test data를 사용하여 모델의 성능을 확인

# %%
# tokenization 과정까지 진행된 최종적으로 모델에 입력될 데이터를 출력합니다.
def prepare_test_dataset(config,preprocessor, tokenizer):

    test_file_path = os.path.join(config['general']['data_path'],'test_preprocessed.csv')

    test_data = preprocessor.make_set_as_df(test_file_path,is_train=False)
    test_id = test_data['fname']

    print('-'*150)
    print(f'test_data:\n{test_data["dialogue"][0]}')
    print('-'*150)

    encoder_input_test , decoder_input_test = preprocessor.make_input(test_data,is_test=True)
    print('-'*10, 'Load data complete', '-'*10,)

    test_tokenized_encoder_inputs = tokenizer(encoder_input_test, return_tensors="pt", padding=True,
                    add_special_tokens=True, truncation=True, max_length=config['tokenizer']['encoder_max_len'], return_token_type_ids=False,)
    test_tokenized_decoder_inputs = tokenizer(decoder_input_test, return_tensors="pt", padding=True,
                    add_special_tokens=True, truncation=True, max_length=config['tokenizer']['decoder_max_len'], return_token_type_ids=False,)

    test_encoder_inputs_dataset = DatasetForInference(test_tokenized_encoder_inputs, test_id, len(encoder_input_test))
    print('-'*10, 'Make dataset complete', '-'*10,)

    return test_data, test_encoder_inputs_dataset

# %%
# 추론을 위한 tokenizer와 학습시킨 모델을 불러옵니다.
def load_tokenizer_and_model_for_test(config,device):
    print('-'*10, 'Load tokenizer & model', '-'*10,)

    model_name = config['general']['model_name']
    ckt_path = best_path
    print('-'*10, f'Model Name : {model_name}', '-'*10,)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    special_tokens_dict = {'additional_special_tokens': config['tokenizer']['special_tokens']}
    tokenizer.add_special_tokens(special_tokens_dict)

    generate_model = BartForConditionalGeneration.from_pretrained(ckt_path)
    generate_model.resize_token_embeddings(len(tokenizer))
    generate_model.to(device)
    print('-'*10, 'Load tokenizer & model complete', '-'*10,)

    return generate_model , tokenizer

# %% [markdown]
# ### 3) 간단한 후처리

# %%
def clean_summary(text):

    text = text.strip()

    # 1. 앞뒤 쌍따옴표 제거
    if len(text) >= 2 and text[0] == '"' and text[-1] == '"':
        text = text[1:-1].strip()

    # 2. 전체 문자열 내 쌍따옴표 제거
    text = text.replace('"', '')

    # 3. 중복 공백 제거
    text = re.sub(r"\s+", " ", text)

    # 4. 문장부호 앞 공백 제거
    text = re.sub(r"\s+([,.!?])", r"\1", text)

    # 5. #Person 토큰 앞 공백 제거
    text = re.sub(r"#Person(\d+)#\s+", r"#Person\1#", text)

    return text

# %% [markdown]
# ### 4) 추론 수행

# %%
# 학습된 모델이 생성한 요약문의 출력 결과를 보여줍니다.
def inference(config):
    device = torch.device('cuda:0' if torch.cuda.is_available()  else 'cpu')
    print('-'*10, f'device : {device}', '-'*10,)
    print(torch.__version__)

    generate_model , tokenizer = load_tokenizer_and_model_for_test(config,device)

    data_path = config['general']['data_path']
    preprocessor = Preprocess(config['tokenizer']['bos_token'], config['tokenizer']['eos_token'])

    test_data, test_encoder_inputs_dataset = prepare_test_dataset(config,preprocessor, tokenizer)
    dataloader = DataLoader(test_encoder_inputs_dataset, batch_size=config['inference']['batch_size'])

    summary = []
    text_ids = []
    with torch.no_grad():
        for item in tqdm(dataloader):
            text_ids.extend(item['ID'])
            generated_ids = generate_model.generate(input_ids=item['input_ids'].to('cuda:0'),
                            no_repeat_ngram_size=config['inference']['no_repeat_ngram_size'],
                            early_stopping=config['inference']['early_stopping'],
                            max_length=config['inference']['generate_max_length'],
                            num_beams=config['inference']['num_beams'],
                        )
            for ids in generated_ids:
                result = tokenizer.decode(ids)
                summary.append(result)

    # 정확한 평가를 위하여 노이즈에 해당되는 스페셜 토큰을 제거합니다.
    remove_tokens = config['inference']['remove_tokens']
    preprocessed_summary = summary.copy()
    for token in remove_tokens:
        preprocessed_summary = [sentence.replace(token," ") for sentence in preprocessed_summary]

    # 추가적인 후처리
    preprocessed_summary = [clean_summary(text) for text in preprocessed_summary]

    output = pd.DataFrame(
        {
            "fname": test_data['fname'],
            "summary" : preprocessed_summary,
        }
    )
    result_path = config['inference']['result_path']
    if not os.path.exists(result_path):
        os.makedirs(result_path)
    now = datetime.now().strftime("%m%d_%H%M")
    filename = f"output_{now}.csv"
    
    output.to_csv(f"./prediction/{filename}", index=False)

    return output

# %%
# 학습된 모델의 test를 진행합니다.
if __name__ == "__main__":
    output = inference(loaded_config)
# Out:
# ---------- device : cuda:0 ----------
# 2.1.0
# ---------- Load tokenizer & model ----------
# ---------- Model Name : gogamza/kobart-summarization ----------
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# ---------- Load tokenizer & model complete ----------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# test_data:
# #Person1# Ms. Dawson, 받아쓰기 좀 부탁드려야겠어요. #Person2# 네, 말씀하세요... #Person1# 이걸 오늘 오후까지 모든 직원들에게 사내 메모로 보내야 해요. 준비됐나요? #Person2# 네, 말씀하세요. #Person1# 모든 직원에게 알립니다... 즉시 발효되어 모든 사내 통신은 이메일과 공식 메모로만 제한됩니다. 근무 시간 동안 즉시 메시지 프로그램 사용은 금지됩니다. #Person2# 이 정책이 사내 통신에만 적용되나요, 아니면 외부 통신에도 해당되나요? #Person1# 이는 모든 통신에 적용됩니다. 사무실 내 직원 간 통신 뿐만 아니라 외부 통신도 해당됩니다. #Person2# 하지만 많은 직원들이 고객과 소통하려고 즉시 메시지를 사용합니다. #Person1# 통신 방법을 바꿔야 할 것입니다. 이 사무실에서는 즉시 메시지를 사용하는 것을 원하지 않습니다. 너무 많은 시간이 낭비됩니다! 이제 계속해서 메모를 작성해 주세요. 어디까지 했죠? #Person2# 내외부 통신에 적용됩니다. #Person1# 네. 즉시 메시지를 계속 사용하면 경고 후 시정 조치가 이루어지며, 두 번째 위반 시 해고될 수 있습니다. 이번 정책에 관한 질문은 부서장에게 문의하세요. #Person2# 그게 다인가요? #Person1# 네. 오늘 오후 4시까지 이 메모를 작성하고 배포해주세요.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------- Load data complete ----------
# ---------- Make dataset complete ----------
# 100%|██████████| 32/32 [00:29<00:00,  1.09it/s]
#  Ms. Dawson은 #Person1#에게 사내 메모를 작성하고 배포하라고 요청합니다. Ms.는 즉시 메시지가 제한되며, 외부 통신은 사내 통신에만 적용된다고 설명합니다. #Person1#은 메모를 계속 작성하면 경고 후 해고될 수 있다고 경고합니다.
# Ms. Dawson은 #Person1#에게 사내 메모를 작성하고 배포하라고 요청합니다. Ms.는 즉시 메시지가 제한되며, 외부 통신은 사내 통신에만 적용된다고 설명합니다. #Person1#은 메모를 계속 작성하면 경고 후 해고될 수 있다고 경고합니다.
# ===================
#  #Person1#과 #Person2#는 출퇴근 시간에 교통체증을 피하기 위해 대중교통을 이용하기로 결정합니다. #Person1#은 대중교통이 환경에도 더 좋다고 생각하며, #Person2#에게 자전거로 출근하라고 제안합니다.
# #Person1#과 #Person2#는 출퇴근 시간에 교통체증을 피하기 위해 대중교통을 이용하기로 결정합니다. #Person1#은 대중교통이 환경에도 더 좋다고 생각하며, #Person2#에게 자전거로 출근하라고 제안합니다.
# ===================
#  Kate는 Masha와 Hero가 이혼했다고 #Person1#에게 말합니다. Kate는 그들이 잘 어울리는 커플이라고 생각했습니다.
# Kate는 Masha와 Hero가 이혼했다고 #Person1#에게 말합니다. Kate는 그들이 잘 어울리는 커플이라고 생각했습니다.
# ===================
#  #Person1#은 Brian의 생일을 축하하며 파티에서 함께 춤을 추자고 제안합니다.
# #Person1#은 Brian의 생일을 축하하며 파티에서 함께 춤을 추자고 제안합니다.
# ===================
#  #Person1#과 #Person2#는 올림픽 공원의 크기와 시설에 대해 이야기합니다. #Person1#은 전체 스타디움의 좌석이 5000석이라고 설명하고, 외국인 방문객을 위한 영어 번역 표지판을 설치했습니다.
# #Person1#과 #Person2#는 올림픽 공원의 크기와 시설에 대해 이야기합니다. #Person1#은 전체 스타디움의 좌석이 5000석이라고 설명하고, 외국인 방문객을 위한 영어 번역 표지판을 설치했습니다.
# ===================
#  #Person1#은 #Person2#에게 회사를 차리기 위해 사업 계획서를 작성하고 투자자를 모으는 것이 어렵다고 말합니다. #Person2#는 사업 계획서에 사업 아이디어를 두 페이지 이내로 요약한 부분이 포함되어야 하며, 시장 분석과 사회경제적 요인을 포함해야 한다고 설명합니다. #Person1#은 사업 시작의 번거로움을 피하라고 조언합니다.
# #Person1#은 #Person2#에게 회사를 차리기 위해 사업 계획서를 작성하고 투자자를 모으는 것이 어렵다고 말합니다. #Person2#는 사업 계획서에 사업 아이디어를 두 페이지 이내로 요약한 부분이 포함되어야 하며, 시장 분석과 사회경제적 요인을 포함해야 한다고 설명합니다. #Person1#은 사업 시작의 번거로움을 피하라고 조언합니다.
# ===================
#  #Person2#는 #Person1#에게 수두에 걸렸다고 말하며, #Person1#은 #Person2#에게 가까이 오지 말라고 경고한다.
# #Person2#는 #Person1#에게 수두에 걸렸다고 말하며, #Person1#은 #Person2#에게 가까이 오지 말라고 경고한다.
# ===================
#  #Person1#은 #Person2#에게 세탁 서비스 요금에 30달러가 추가되었다고 알립니다. #Person2#는 관련 부서에 확인해 달라고 요청합니다.
# #Person1#은 #Person2#에게 세탁 서비스 요금에 30달러가 추가되었다고 알립니다. #Person2#는 관련 부서에 확인해 달라고 요청합니다.
# ===================
#  스티븐은 아내가 비서와 바람피운 것을 알고 이혼을 결심했다. #Person1#은 스티븐에게 최선을 다해 설득할 것이다.
# 스티븐은 아내가 비서와 바람피운 것을 알고 이혼을 결심했다. #Person1#은 스티븐에게 최선을 다해 설득할 것이다.
# ===================
#  #Person2#는 #Person1#에게 유명한 사람들에 대해 이야기하며, 아브라함 링컨과 평등한 권리를 위해 싸운 용사를 존경한다고 말합니다.
# #Person2#는 #Person1#에게 유명한 사람들에 대해 이야기하며, 아브라함 링컨과 평등한 권리를 위해 싸운 용사를 존경한다고 말합니다.
# ===================
#  #Person2#는 #Person1#에게 허베이에 6급 강풍을 동반한 심한 황사가 있다고 전하며, 황사가 호흡기 감염에 미치는 영향에 대해 이야기합니다.
# #Person2#는 #Person1#에게 허베이에 6급 강풍을 동반한 심한 황사가 있다고 전하며, 황사가 호흡기 감염에 미치는 영향에 대해 이야기합니다.
# ===================
#  #Person1#은 Francis의 생일 파티에 초대받았고, #Person2#는 원격 조종 자동차 모델을 추천하며 #Person1#에게 그 차를 보여줍니다.
# #Person1#은 Francis의 생일 파티에 초대받았고, #Person2#는 원격 조종 자동차 모델을 추천하며 #Person1#에게 그 차를 보여줍니다.
# ===================
#  Tony는 Steven에게 부정행위를 하다가 들켜서 부끄러움을 느끼고 있다고 말한다. 그는 열심히 공부해야 한다고 강조한다.
# Tony는 Steven에게 부정행위를 하다가 들켜서 부끄러움을 느끼고 있다고 말한다. 그는 열심히 공부해야 한다고 강조한다.
# ===================
#  톰은 8시 50분으로 늦었습니다. #Person1#은 기차를 타기 위해 서둘러야 한다고 말합니다.
# 톰은 8시 50분으로 늦었습니다. #Person1#은 기차를 타기 위해 서둘러야 한다고 말합니다.
# ===================
#  #Person1#은 #Person2#에게 자신의 삶을 어떻게 조정해야 할지 조언을 구합니다.
# #Person1#은 #Person2#에게 자신의 삶을 어떻게 조정해야 할지 조언을 구합니다.
# ===================
#  #Person1#은 #Person2#에게 Ruojia의 결혼 소식을 전하고, #Person2#는 그녀의 트위터에서 그 소식을 보고 이메일도 확인했습니다. #Person1#은 파티를 위해 와인잔과 결혼 축하 카드를 가져갈 예정입니다.
# #Person1#은 #Person2#에게 Ruojia의 결혼 소식을 전하고, #Person2#는 그녀의 트위터에서 그 소식을 보고 이메일도 확인했습니다. #Person1#은 파티를 위해 와인잔과 결혼 축하 카드를 가져갈 예정입니다.
# ===================
#  #Person1#은 #Person2#에게 스트립을 잡아당기고, 뒷면을 떼어내면 적에게 공격받을 수 있다고 경고합니다.
# #Person1#은 #Person2#에게 스트립을 잡아당기고, 뒷면을 떼어내면 적에게 공격받을 수 있다고 경고합니다.
# ===================
#  마이크의 여동생이 #Person1#의 여동생과 비슷하다고 생각한다.
# 마이크의 여동생이 #Person1#의 여동생과 비슷하다고 생각한다.
# ===================
#  #Person2#가 머리가 아파서 #Person1#에게 도움을 요청합니다.
# #Person2#가 머리가 아파서 #Person1#에게 도움을 요청합니다.
# ===================
#  #Person2#는 카메라와 MP3 플레이어가 있는 새 휴대폰을 사고 싶어 합니다.
# #Person2#는 카메라와 MP3 플레이어가 있는 새 휴대폰을 사고 싶어 합니다.
# ===================
#  프랭크 주디가 프랭크의 새 직장에 지원한 이유는 정부가 직원들에게 좋은 건강보험 혜택을 제공하기 때문이다.
# 프랭크 주디가 프랭크의 새 직장에 지원한 이유는 정부가 직원들에게 좋은 건강보험 혜택을 제공하기 때문이다.
# ===================
#  #Person2#는 #Person1#에게 컴퓨터 프로그램을 작성하고 비서 업무를 수행할 수 있으며, 의사 면허증과 운전 면허증을 보유하고 있다고 설명합니다. 또한, #Person2#는 IBMPC에 대한 경험이 있으며, 타자, 속기, 팩스 기계 운용 등 특별한 훈련을 받았다고 말합니다.
# #Person2#는 #Person1#에게 컴퓨터 프로그램을 작성하고 비서 업무를 수행할 수 있으며, 의사 면허증과 운전 면허증을 보유하고 있다고 설명합니다. 또한, #Person2#는 IBMPC에 대한 경험이 있으며, 타자, 속기, 팩스 기계 운용 등 특별한 훈련을 받았다고 말합니다.
# ===================
#  #Person2#가 #Person1#의 도움으로 미디엄 레어 스테이크를 주문합니다.
# #Person2#가 #Person1#의 도움으로 미디엄 레어 스테이크를 주문합니다.
# ===================
#  Tom은 #Person1#의 소설이 노벨상을 받았다는 소식을 듣고 기뻐합니다.
# Tom은 #Person1#의 소설이 노벨상을 받았다는 소식을 듣고 기뻐합니다.
# ===================
#  #Person2#는 #Person1#에게 자신이 학생 엔지니어로서 다양한 재료의 기계적 강도와 부식 저항성에 대해 연구한 경험을 이야기합니다.
# #Person2#는 #Person1#에게 자신이 학생 엔지니어로서 다양한 재료의 기계적 강도와 부식 저항성에 대해 연구한 경험을 이야기합니다.
# ===================
#  #Person2#는 일주일에 두세 번 술을 마십니다. #Person1#은 램 바 그릴에서 피처 프로모션을 한다고 말합니다. #Person2#는 맥주를 좋아하지만 세 잔 이상 마시면 두통이 온다고 느낍니다.
# #Person2#는 일주일에 두세 번 술을 마십니다. #Person1#은 램 바 그릴에서 피처 프로모션을 한다고 말합니다. #Person2#는 맥주를 좋아하지만 세 잔 이상 마시면 두통이 온다고 느낍니다.
# ===================
#  메이는 다니엘에게 소풍을 준비하는 것을 도와달라고 요청하지만, 엄마는 거실로 옮기는 것이 더 번거롭다고 느낍니다.
# 메이는 다니엘에게 소풍을 준비하는 것을 도와달라고 요청하지만, 엄마는 거실로 옮기는 것이 더 번거롭다고 느낍니다.
# ===================
#  James는 새 계정을 통해 Muriel Douglas 씨에게 새 가족과 함께 Tahoe에 스키를 타러 갔다고 알립니다. James의 동료 Susan Kim도 곧 올 예정입니다.
# James는 새 계정을 통해 Muriel Douglas 씨에게 새 가족과 함께 Tahoe에 스키를 타러 갔다고 알립니다. James의 동료 Susan Kim도 곧 올 예정입니다.
# ===================
#  #Person1#은 #Person2#에게 유니버설 은행에서 카드를 슬롯에 넣어 달라고 요청합니다. #Person2#는 카드를 제거하고 #Person1#에게 출입구가 봉쇄되었다고 알립니다.
# #Person1#은 #Person2#에게 유니버설 은행에서 카드를 슬롯에 넣어 달라고 요청합니다. #Person2#는 카드를 제거하고 #Person1#에게 출입구가 봉쇄되었다고 알립니다.
# ===================
#  #Person2#는 #Person1#에게 직장 동료들과의 대화에서 가장 중요한 것은 진심이라고 말합니다.
# #Person2#는 #Person1#에게 직장 동료들과의 대화에서 가장 중요한 것은 진심이라고 말합니다.
# ===================
#  Mr. Polly는 끔찍한 일을 잠시 쉬고 싶어 하며, 상사가 음료수를 사주기로 합니다.
# Mr. Polly는 끔찍한 일을 잠시 쉬고 싶어 하며, 상사가 음료수를 사주기로 합니다.
# ===================
#  모니카는 프랜시스에게 재무 보고서를 금요일 오후 1시부터 4시까지 작업할 수 있는지 문의하고, 프랜시스는 금요일 오후에 보고서를 검토할 시간을 찾기로 합니다.
# 모니카는 프랜시스에게 재무 보고서를 금요일 오후 1시부터 4시까지 작업할 수 있는지 문의하고, 프랜시스는 금요일 오후에 보고서를 검토할 시간을 찾기로 합니다.
# ===================
#  #Person2#는 다음 주 인터뷰를 준비하기 위해 워크숍에 참가합니다. #Person1#은 #Person2#에게 인터뷰에 필요한 고려사항과 정직하게 대답하라고 조언합니다.
# #Person2#는 다음 주 인터뷰를 준비하기 위해 워크숍에 참가합니다. #Person1#은 #Person2#에게 인터뷰에 필요한 고려사항과 정직하게 대답하라고 조언합니다.
# ===================
#  Mike는 Jason과 Laura가 상처받고 슬픈 연기를 하고 있다고 생각하지만, 컷은 그녀의 감정과 대사가 적절하지 않다고 판단합니다.
# Mike는 Jason과 Laura가 상처받고 슬픈 연기를 하고 있다고 생각하지만, 컷은 그녀의 감정과 대사가 적절하지 않다고 판단합니다.
# ===================
#  이만 Mrs. Todd에게 아내가 쇼핑 가자고 기다리고 있다고 알립니다. Mr.Todd는 #Person1#이 먼저 방문했어야 했다고 생각합니다.
# 이만 Mrs. Todd에게 아내가 쇼핑 가자고 기다리고 있다고 알립니다. Mr.Todd는 #Person1#이 먼저 방문했어야 했다고 생각합니다.
# ===================
#  빌은 이번 주에 매일 밤 일했기 때문에 피곤하다고 #Person1#에게 말합니다. #Person1#은 빌의 형을 만나기 위해 시간을 확인하려고 합니다.
# 빌은 이번 주에 매일 밤 일했기 때문에 피곤하다고 #Person1#에게 말합니다. #Person1#은 빌의 형을 만나기 위해 시간을 확인하려고 합니다.
# ===================
#  Simon은 Cleo에게 내일 핵무기 확산을 막는 데 도움을 주는 시위에 가자고 제안하지만, 시위에 대한 이해 부족과 책임 있는 시민으로서 자신의 신념을 지키는 것이 중요하다고 강조하며 물리 시험 공부로 가기로 결정한다.
# Simon은 Cleo에게 내일 핵무기 확산을 막는 데 도움을 주는 시위에 가자고 제안하지만, 시위에 대한 이해 부족과 책임 있는 시민으로서 자신의 신념을 지키는 것이 중요하다고 강조하며 물리 시험 공부로 가기로 결정한다.
# ===================
#  #Person1#은 #Person2#에게 누군가가 문을 두드리거나 가스라고 하면 괜찮다고 생각하게 된다고 말합니다.
# #Person1#은 #Person2#에게 누군가가 문을 두드리거나 가스라고 하면 괜찮다고 생각하게 된다고 말합니다.
# ===================
#  Maggie는 Mark에게 카페테리아에서 노트를 복사해 도서관에서 복사할 것을 제안하고, Mrk는 함께 공부할 사람과 깨어 있을 사람이 필요하다고 동의한다.
# Maggie는 Mark에게 카페테리아에서 노트를 복사해 도서관에서 복사할 것을 제안하고, Mrk는 함께 공부할 사람과 깨어 있을 사람이 필요하다고 동의한다.
# ===================
#  #Person1#은 Turner 교수님의 지질학 고급 과목을 다시 수강하고 싶어합니다. #Person2#는 #Person1#에게 Burman 교수님의 수업을 추천하고, #Person1#은 이에 동의합니다.
# #Person1#은 Turner 교수님의 지질학 고급 과목을 다시 수강하고 싶어합니다. #Person2#는 #Person1#에게 Burman 교수님의 수업을 추천하고, #Person1#은 이에 동의합니다.
# ===================
#  #Person1#은 #Person2#의 가게에서 펜던트를 깨뜨려 새 것으로 교환해 줍니다.
# #Person1#은 #Person2#의 가게에서 펜던트를 깨뜨려 새 것으로 교환해 줍니다.
# ===================
#  #Person2#는 박싱 데이 세일에 맞춰 이모가 준 스웨터를 입고 있으며, #Person1#은 #Person2#의 바보 같은 게임을 즐깁니다.
# #Person2#는 박싱 데이 세일에 맞춰 이모가 준 스웨터를 입고 있으며, #Person1#은 #Person2#의 바보 같은 게임을 즐깁니다.
# ===================
#  #Person2#는 미디어 업계에서 일하는 것이 재미있을 것 같아 TV 뉴스 디렉터가 되고 싶어 한다. #Person1#은 컴퓨터와 일하는 것을 선호한다.
# #Person2#는 미디어 업계에서 일하는 것이 재미있을 것 같아 TV 뉴스 디렉터가 되고 싶어 한다. #Person1#은 컴퓨터와 일하는 것을 선호한다.
# ===================
#  #Person1#과 #Person2#는 지루한 연설을 하고 있습니다. #Person1#은 #Person2#에게 지루하더라도 나한텐 여기 머물러야 한다고 말합니다. #Person2#의 가방에는 옛날 신문이 있을지도 모르며, 퍼즐 같은 게임도 있을 수 있습니다.
# #Person1#과 #Person2#는 지루한 연설을 하고 있습니다. #Person1#은 #Person2#에게 지루하더라도 나한텐 여기 머물러야 한다고 말합니다. #Person2#의 가방에는 옛날 신문이 있을지도 모르며, 퍼즐 같은 게임도 있을 수 있습니다.
# ===================
#  사라는와 #Person1#은 도시 중심에서 조금 떨어진 곳에 더 저렴한 집을 사는 것을 제안합니다. 사라는 그 제안이 좋은 생각이라고 생각합니다.
# 사라는와 #Person1#은 도시 중심에서 조금 떨어진 곳에 더 저렴한 집을 사는 것을 제안합니다. 사라는 그 제안이 좋은 생각이라고 생각합니다.
# ===================
#  Mark Leach는 People You Meet에서 영국 관광청의 관광 사무소에서 정보 담당관으로 일하며 총 13개의 언어로 서비스를 제공한다고 설명합니다. 그는 런던에서의 당일 여행과 2주간 여행을 계획하는 데 도움을 줍니다.
# Mark Leach는 People You Meet에서 영국 관광청의 관광 사무소에서 정보 담당관으로 일하며 총 13개의 언어로 서비스를 제공한다고 설명합니다. 그는 런던에서의 당일 여행과 2주간 여행을 계획하는 데 도움을 줍니다.
# ===================
#  Lin Fang과 Lucy는 다음 수업에 대해 이야기한다. 둘 다 영어가 가장 좋아하는 과목이고, 중국어 및 과학을 좋아한다.
# Lin Fang과 Lucy는 다음 수업에 대해 이야기한다. 둘 다 영어가 가장 좋아하는 과목이고, 중국어 및 과학을 좋아한다.
# ===================
#  James가 Mrs. Thomas에게 집의 낙엽을 치우고 개 Oscar와 Robbie를 산책시켜 달라고 요청합니다. James는 주말에 할아버지를 뵈러 갈 예정입니다.
# James가 Mrs. Thomas에게 집의 낙엽을 치우고 개 Oscar와 Robbie를 산책시켜 달라고 요청합니다. James는 주말에 할아버지를 뵈러 갈 예정입니다.
# ===================
#  #Person1#과 #Person2#는 봄이 왔다고 생각하지만 밤에는 여전히 추워 걱정하고 있습니다. 그들은 창문을 통해 들어오는 햇볕에 대해 이야기합니다.
# #Person1#과 #Person2#는 봄이 왔다고 생각하지만 밤에는 여전히 추워 걱정하고 있습니다. 그들은 창문을 통해 들어오는 햇볕에 대해 이야기합니다.
# ===================
#  Mike는 Jason과 Laura의 반응이 화와 슬픔이 동시에 나와야 한다고 생각하지만, #Person2#는 자신의 방식대로 해보라고 제안합니다.
# Mike는 Jason과 Laura의 반응이 화와 슬픔이 동시에 나와야 한다고 생각하지만, #Person2#는 자신의 방식대로 해보라고 제안합니다.
# ===================
#  #Person1#은 #Person2#에게 프렌드쉽 호텔로 빨리 가라고 요청하고, 요금은 미터기에 15위안입니다.
# #Person1#은 #Person2#에게 프렌드쉽 호텔로 빨리 가라고 요청하고, 요금은 미터기에 15위안입니다.
# ===================
#  #Person2#는 배고파서 과자를 사서 다른 버스를 타야 합니다. #Person1#은 #Person2#에게 환승권을 발급해 줍니다.
# #Person2#는 배고파서 과자를 사서 다른 버스를 타야 합니다. #Person1#은 #Person2#에게 환승권을 발급해 줍니다.
# ===================
#  #Person2#는 #Person1#에게 시내에서 차로 15분 거리에 있으며, 7층이 #Person1#의 회사 건물의 6층과 7층을 사용하고 있다고 설명합니다.
# #Person2#는 #Person1#에게 시내에서 차로 15분 거리에 있으며, 7층이 #Person1#의 회사 건물의 6층과 7층을 사용하고 있다고 설명합니다.
# ===================
#  #Person2#는 #Person1#에게 Lulu가 Vic과 헤어졌고 전근 신청했다고 전한다.
# #Person2#는 #Person1#에게 Lulu가 Vic과 헤어졌고 전근 신청했다고 전한다.
# ===================
#  샐리가 데이브 톰슨에게 짐이 아직 돌아오지 않았다고 알립니다. 톰슨은 샐리에게 전화를 걸어 짐이 펍에 들렀을 가능성을 언급합니다.
# 샐리가 데이브 톰슨에게 짐이 아직 돌아오지 않았다고 알립니다. 톰슨은 샐리에게 전화를 걸어 짐이 펍에 들렀을 가능성을 언급합니다.
# ===================
#  #Person2#는 #Person1#에게 시청으로 가는 길을 안내합니다. #Person1#은 #Person2#에게 다시 한 번 설명해 달라고 요청합니다.
# #Person2#는 #Person1#에게 시청으로 가는 길을 안내합니다. #Person1#은 #Person2#에게 다시 한 번 설명해 달라고 요청합니다.
# ===================
#  #Person1#은 #Person2#에게 여권을 잃어버렸다고 알립니다. #Person2#는 백화점의 신발 코너에서 여권이 발견되지 않았다고 설명합니다. #Person1#은 대사관에 상황을 알리고 새 여권을 발급받을 수 있도록 연락하라고 조언합니다.
# #Person1#은 #Person2#에게 여권을 잃어버렸다고 알립니다. #Person2#는 백화점의 신발 코너에서 여권이 발견되지 않았다고 설명합니다. #Person1#은 대사관에 상황을 알리고 새 여권을 발급받을 수 있도록 연락하라고 조언합니다.
# ===================
#  Leah는 Nathaniel에게 Ms. Collins가 전화를 받지 못해 다음 주까지 돌아오지 못할 것 같다고 알립니다. 그녀는 다른 사람과 약속을 잡기 위해 오전 11시 30분에 약속을 잡았습니다.
# Leah는 Nathaniel에게 Ms. Collins가 전화를 받지 못해 다음 주까지 돌아오지 못할 것 같다고 알립니다. 그녀는 다른 사람과 약속을 잡기 위해 오전 11시 30분에 약속을 잡았습니다.
# ===================
#  #Person1#은 #Person2#에게 Dick에게 결혼하지 않겠다고 말했을 때 놀랐다고 말합니다.
# #Person1#은 #Person2#에게 Dick에게 결혼하지 않겠다고 말했을 때 놀랐다고 말합니다.
# ===================
#  #Person1#과 #Person2#는 파티에서 만난 금발 여자에 대해 이야기합니다. #Person1#은 Janice에게 말 걸어보라고 제안하지만, Janise는 긴장되고 바보처럼 보인다고 느낍니다. 결국 그들은 한 잔 더 마시기로 합니다.
# #Person1#과 #Person2#는 파티에서 만난 금발 여자에 대해 이야기합니다. #Person1#은 Janice에게 말 걸어보라고 제안하지만, Janise는 긴장되고 바보처럼 보인다고 느낍니다. 결국 그들은 한 잔 더 마시기로 합니다.
# ===================
#  Jack은 #Person1#에게 정치학, 비즈니스 커뮤니케이션, 비즈니스 커뮤니케이션 수업을 가장 좋아한다고 말합니다.
# Jack은 #Person1#에게 정치학, 비즈니스 커뮤니케이션, 비즈니스 커뮤니케이션 수업을 가장 좋아한다고 말합니다.
# ===================
#  #Person1#과 #Person2#는 어젯밤에 내린 비에 대해 이야기하며, 베이징의 가을은 아름답지만 여름에는 너무 더운 것 같다고 이야기합니다. #Person1#은 #Person2#에게 베이징의 봄은 따뜻하지만 겨울에는 너무 춥다고 말합니다.
# #Person1#과 #Person2#는 어젯밤에 내린 비에 대해 이야기하며, 베이징의 가을은 아름답지만 여름에는 너무 더운 것 같다고 이야기합니다. #Person1#은 #Person2#에게 베이징의 봄은 따뜻하지만 겨울에는 너무 춥다고 말합니다.
# ===================
#  #Person1#은 #Person2#에게 공포 영화, 탐정 영화, 로맨스 영화, 전쟁 영화를 보러 가자고 제안하지만, #Person2#는 여자애가 전쟁 영화를 보고 싶어한다는 것이 상상이 안 간다고 답합니다.
# #Person1#은 #Person2#에게 공포 영화, 탐정 영화, 로맨스 영화, 전쟁 영화를 보러 가자고 제안하지만, #Person2#는 여자애가 전쟁 영화를 보고 싶어한다는 것이 상상이 안 간다고 답합니다.
# ===================
#  Adam은 #Person1#에게 학교 안내를 위해 학교 건물, 학교 수영장, 그리고 도서관에 대해 설명합니다.
# Adam은 #Person1#에게 학교 안내를 위해 학교 건물, 학교 수영장, 그리고 도서관에 대해 설명합니다.
# ===================
#  #Person1#과 #Person2#는 임신 소식을 듣고 기뻐하고 있다.
# #Person1#과 #Person2#는 임신 소식을 듣고 기뻐하고 있다.
# ===================
#  #Person1#은 #Person2#에게 John이 일주일에 일곱 번 그녀와 데이트한다고 말합니다.
# #Person1#은 #Person2#에게 John이 일주일에 일곱 번 그녀와 데이트한다고 말합니다.
# ===================
#  #Person1#은 #Person2#에게 소프트웨어에 그림 그리기 프로그램을 추가하고 하드웨어도 업그레이드할 것을 제안합니다.
# #Person1#은 #Person2#에게 소프트웨어에 그림 그리기 프로그램을 추가하고 하드웨어도 업그레이드할 것을 제안합니다.
# ===================
#  Que bien은 중국에서 왔고 #Person1#은 미국에서 태어났으며 콜롬비아 출신입니다. 그녀는 스페인어로 시를 썼습니다.
# Que bien은 중국에서 왔고 #Person1#은 미국에서 태어났으며 콜롬비아 출신입니다. 그녀는 스페인어로 시를 썼습니다.
# ===================
#  #Person1#은 #Person2#에게 다이어트를 시도해보라고 제안하고, #Person2#는 운동 수업에 가보라고 제안합니다.
# #Person1#은 #Person2#에게 다이어트를 시도해보라고 제안하고, #Person2#는 운동 수업에 가보라고 제안합니다.
# ===================
#  James는 식당 홀의 창가 자리를 예약했으나 방이 준비되지 않아 방에서 기다리기로 했습니다.
# James는 식당 홀의 창가 자리를 예약했으나 방이 준비되지 않아 방에서 기다리기로 했습니다.
# ===================
#  #Person2#는 #Person1#에게 공장이 75,000 평방미터의 면적에 있으며, 곧 50주년을 맞이할 예정이라고 설명합니다.
# #Person2#는 #Person1#에게 공장이 75,000 평방미터의 면적에 있으며, 곧 50주년을 맞이할 예정이라고 설명합니다.
# ===================
#  Rebecca는 대학 졸업 후 첫 직장으로 York Herald라는 지역 신문에서 인턴을 시작했습니다. 이후 주니어 로컬 뉴스 리포터로 자리를 제안받았고, 2006년에 그곳을 떠나 전국 신문사에서 자리를 찾았습니다.
# Rebecca는 대학 졸업 후 첫 직장으로 York Herald라는 지역 신문에서 인턴을 시작했습니다. 이후 주니어 로컬 뉴스 리포터로 자리를 제안받았고, 2006년에 그곳을 떠나 전국 신문사에서 자리를 찾았습니다.
# ===================
#  #Person1#과 #Person2#는 조별 발표를 위한 쇼핑 리스트 작성을 위해 문구점에 가기로 했습니다. #Person1#은 마커, 색연필, 가위, 형광펜, 자도 필요하며, 압정, 수정액, 종이클립도 필요하다고 말합니다.
# #Person1#과 #Person2#는 조별 발표를 위한 쇼핑 리스트 작성을 위해 문구점에 가기로 했습니다. #Person1#은 마커, 색연필, 가위, 형광펜, 자도 필요하며, 압정, 수정액, 종이클립도 필요하다고 말합니다.
# ===================
#  Mary는 #Person1#에게 인터넷으로 취업 지원 방법을 설명하고, 공식적인 사이트를 통해 구직하는 것을 권장합니다.
# Mary는 #Person1#에게 인터넷으로 취업 지원 방법을 설명하고, 공식적인 사이트를 통해 구직하는 것을 권장합니다.
# ===================
#  #Person2#는 #Person1#에게 한 달에 300달러를 소비할 수 있지만 고지서를 내야 한다고 설명합니다.
# #Person2#는 #Person1#에게 한 달에 300달러를 소비할 수 있지만 고지서를 내야 한다고 설명합니다.
# ===================
#  Jane은 Henry에게 Susan을 보러 병원에 가려면 7번 버스를 타야 한다고 설명한다.
# Jane은 Henry에게 Susan을 보러 병원에 가려면 7번 버스를 타야 한다고 설명한다.
# ===================
#  #Person1#은 내년 판매 예측에 대해 #Person2#와 이야기하고 싶어 하지만, #Person2#는 #Person1#의 스프레드시트 사용 방법을 이해하지 못해 다음 주 화요일 오후 2시 30분에 만나기로 결정합니다.
# #Person1#은 내년 판매 예측에 대해 #Person2#와 이야기하고 싶어 하지만, #Person2#는 #Person1#의 스프레드시트 사용 방법을 이해하지 못해 다음 주 화요일 오후 2시 30분에 만나기로 결정합니다.
# ===================
#  #Person2#는 뉴욕에서의 친구라는 개인 관광 안내 서비스에 대해 #Person1#에게 조언을 구합니다.
# #Person2#는 뉴욕에서의 친구라는 개인 관광 안내 서비스에 대해 #Person1#에게 조언을 구합니다.
# ===================
#  Mr. Jackson은 #Person2#에게 회사가 세계에서 가장 크고 좋은 회사라고 설명합니다. #Person2#는 영업부에서 일하고 싶어하며, 월 2,000 위안을 받습니다. #Person1#은 영업부에서 일할 수 있으며, 3개월 후에 급여가 인상됩니다. 보험과 건강 보험은 #Person1#이 대신 처리할 수 있습니다.
# Mr. Jackson은 #Person2#에게 회사가 세계에서 가장 크고 좋은 회사라고 설명합니다. #Person2#는 영업부에서 일하고 싶어하며, 월 2,000 위안을 받습니다. #Person1#은 영업부에서 일할 수 있으며, 3개월 후에 급여가 인상됩니다. 보험과 건강 보험은 #Person1#이 대신 처리할 수 있습니다.
# ===================
#  #Person1#은 계약서에 서명하지 않았습니다. #Person2#는 계약서가 내일까지 준비될 것이라고 말하며, 포장 관련 조건에 대해 설명합니다. #Person1#은 동의하면 계약서를 작성하겠다고 약속합니다.
# #Person1#은 계약서에 서명하지 않았습니다. #Person2#는 계약서가 내일까지 준비될 것이라고 말하며, 포장 관련 조건에 대해 설명합니다. #Person1#은 동의하면 계약서를 작성하겠다고 약속합니다.
# ===================
#  #Person1#은 ABC 렌터카를 렌트하여 나이아가라 폭포로 가던 중 국경 근처에서 발생한 교통사고에 대해 #Person2#에게 도움을 요청합니다.
# #Person1#은 ABC 렌터카를 렌트하여 나이아가라 폭포로 가던 중 국경 근처에서 발생한 교통사고에 대해 #Person2#에게 도움을 요청합니다.
# ===================
#  #Person2#가 #Person1#에게 학교 보건실로 가는 길을 안내합니다.
# #Person2#가 #Person1#에게 학교 보건실로 가는 길을 안내합니다.
# ===================
#  #Person2#는 짐 엘리베이터 소음으로 인해 방을 바꾸고 싶어 합니다. #Person1#은 #Person2#에게 내일까지 기다려달라고 요청합니다.
# #Person2#는 짐 엘리베이터 소음으로 인해 방을 바꾸고 싶어 합니다. #Person1#은 #Person2#에게 내일까지 기다려달라고 요청합니다.
# ===================
#  #Person1#은 Mr. Wu를 베이징 연회에 초대하기 위해 #Person2#의 짐을 트렁크에 넣습니다. #Person2#는 저녁에 #Person1#을 위한 연회를 위해 국제 호텔에서 픽업할 예정입니다.
# #Person1#은 Mr. Wu를 베이징 연회에 초대하기 위해 #Person2#의 짐을 트렁크에 넣습니다. #Person2#는 저녁에 #Person1#을 위한 연회를 위해 국제 호텔에서 픽업할 예정입니다.
# ===================
#  #Person1#은 길을 잃었습니다. #Person2#는 #Person1#에게 유이창으로 가는 길을 안내합니다.
# #Person1#은 길을 잃었습니다. #Person2#는 #Person1#에게 유이창으로 가는 길을 안내합니다.
# ===================
#  #Person2#는 Mr. Li에게 조언을 구했지만 해결하지 못했습니다. #Person1#은 수리공에게 연락하라고 제안합니다.
# #Person2#는 Mr. Li에게 조언을 구했지만 해결하지 못했습니다. #Person1#은 수리공에게 연락하라고 제안합니다.
# ===================
#  #Person2#는 #Person1#의 가게에서 어머니 생신 선물로 금색 목걸이와 숫자가 크고 명확한 새 시계를 구매합니다.
# #Person2#는 #Person1#의 가게에서 어머니 생신 선물로 금색 목걸이와 숫자가 크고 명확한 새 시계를 구매합니다.
# ===================
#  Ms. Fisher는 Ms. Ross에게 전화를 걸어 뉴질랜드에 지점을 열 계획이라고 알리고, 발표 전에 커피, 스낵 뷔페, 전시용 스탠드, 오버헤드 프로젝터, 음향 시스템이 준비될 것이라고 알립니다.
# Ms. Fisher는 Ms. Ross에게 전화를 걸어 뉴질랜드에 지점을 열 계획이라고 알리고, 발표 전에 커피, 스낵 뷔페, 전시용 스탠드, 오버헤드 프로젝터, 음향 시스템이 준비될 것이라고 알립니다.
# ===================
#  #Person2#는 #Person1#에게 러시아와 캐나다의 차이점에 대해 설명합니다. 러시아에서는 모든 것이 빠르게 진행되지만, 캐나다에서는 은행 가는 데 몇 시간이 걸리며, 공공 서비스는 느리게 운영됩니다. #Person1#은 캐나다 사람들이 일반적으로 러시아 사람들보다 더 차분하다고 생각하지만, #Person2#는 캐나다 사람들이 더 여유롭다고 말합니다.
# #Person2#는 #Person1#에게 러시아와 캐나다의 차이점에 대해 설명합니다. 러시아에서는 모든 것이 빠르게 진행되지만, 캐나다에서는 은행 가는 데 몇 시간이 걸리며, 공공 서비스는 느리게 운영됩니다. #Person1#은 캐나다 사람들이 일반적으로 러시아 사람들보다 더 차분하다고 생각하지만, #Person2#는 캐나다 사람들이 더 여유롭다고 말합니다.
# ===================
#  #Person2#는 #Person1#에게 카리브해로 여행을 가기로 결정하면 운이 좋기를 바란다고 말합니다.
# #Person2#는 #Person1#에게 카리브해로 여행을 가기로 결정하면 운이 좋기를 바란다고 말합니다.
# ===================
#  #Person1#은 소풍에 가져갈 과일로 오렌지와 바나나를 준비하고, #Person2#는 포도나 사과를 가져가기로 합니다.
# #Person1#은 소풍에 가져갈 과일로 오렌지와 바나나를 준비하고, #Person2#는 포도나 사과를 가져가기로 합니다.
# ===================
#  #Person2#는 #Person1#에게 경제형 차량 렌트 비용과 운전면허증을 제시합니다.
# #Person2#는 #Person1#에게 경제형 차량 렌트 비용과 운전면허증을 제시합니다.
# ===================
#  #Person1#은 #Person2#에게 엘리베이터에서 웃으면 다른 사람들을 불편하게 만들 수 있다고 말합니다. #Person2#는 무표정한 사람들을 싫어합니다.
# #Person1#은 #Person2#에게 엘리베이터에서 웃으면 다른 사람들을 불편하게 만들 수 있다고 말합니다. #Person2#는 무표정한 사람들을 싫어합니다.
# ===================
#  #Person1#과 #Person2#는 작년 판매 실적에 대해 이야기하고 있습니다. #Person1#은 Wallace의 기여와 새로운 마케팅 전략의 효과로 흑자를 달성했습니다.
# #Person1#과 #Person2#는 작년 판매 실적에 대해 이야기하고 있습니다. #Person1#은 Wallace의 기여와 새로운 마케팅 전략의 효과로 흑자를 달성했습니다.
# ===================
#  #Person2#가 가방을 도난당했습니다. #Person1#은 #Person2#에게 돈을 빌려달라고 부탁합니다. #Person2#는 금요일에 갚을 예정입니다.
# #Person2#가 가방을 도난당했습니다. #Person1#은 #Person2#에게 돈을 빌려달라고 부탁합니다. #Person2#는 금요일에 갚을 예정입니다.
# ===================
#  Lin은 Steven에게 중국에서는 팁을 주지 않는 문명 시스템에 대해 설명한다.
# Lin은 Steven에게 중국에서는 팁을 주지 않는 문명 시스템에 대해 설명한다.
# ===================
#  빌은 #Person1#에게 룸메이트와 헤어졌기 때문에 Brain Locker가 이사했다고 설명한다.
# 빌은 #Person1#에게 룸메이트와 헤어졌기 때문에 Brain Locker가 이사했다고 설명한다.
# ===================
#  Tom Wilson이 호텔에서 4박 동안 식사 요금을 신용카드로 결제합니다.
# Tom Wilson이 호텔에서 4박 동안 식사 요금을 신용카드로 결제합니다.
# ===================
#  캐롤이 샤워 중이라 #Person1#에게 캐롤이 전화할 수 없습니다. #Person1#은 캐롤에게 내일 밤 8시 반에 질의 집에서 파티를 열고, 디저트를 가져오라고 요청합니다.
# 캐롤이 샤워 중이라 #Person1#에게 캐롤이 전화할 수 없습니다. #Person1#은 캐롤에게 내일 밤 8시 반에 질의 집에서 파티를 열고, 디저트를 가져오라고 요청합니다.
# ===================
#  #Person2#는 #Person1#에게 Common Fitness Gym에서 일한 적이 있다고 말합니다. #Person1#은 #Person2#에게 그곳을 가보라고 요청합니다.
# #Person2#는 #Person1#에게 Common Fitness Gym에서 일한 적이 있다고 말합니다. #Person1#은 #Person2#에게 그곳을 가보라고 요청합니다.
# ===================
#  #Person1#은 #Person2#에게 트럼프가 다시 대통령이 될 것이라고 확신하지만, #Person2#는 바이든을 찍을 것이라고 생각합니다.
# #Person1#은 #Person2#에게 트럼프가 다시 대통령이 될 것이라고 확신하지만, #Person2#는 바이든을 찍을 것이라고 생각합니다.
# ===================
#  #Person1#은 ATM을 사용하는 방법을 몰라 #Person2#에게 도움을 요청합니다.
# #Person1#은 ATM을 사용하는 방법을 몰라 #Person2#에게 도움을 요청합니다.
# ===================
#  수잔 밀러는 John에게 사무실 절차에 관한 메모를 준 것에 대해 사과한다.
# 수잔 밀러는 John에게 사무실 절차에 관한 메모를 준 것에 대해 사과한다.
# ===================
#  #Person1#은 Lily에게 이번 주말 소풍을 같이 가자고 제안합니다. #Person1#은 편한 옷과 걷기 좋은 신발을 준비할 것입니다.
# #Person1#은 Lily에게 이번 주말 소풍을 같이 가자고 제안합니다. #Person1#은 편한 옷과 걷기 좋은 신발을 준비할 것입니다.
# ===================
#  #Person1#은 #Person2#에게 중국 연회에 초대된 경험을 이야기합니다. #Person2#는 젓가락을 밥그릇에 꽂거나 향 두 개를 닮아 불길하게 느낀다고 말합니다.
# #Person1#은 #Person2#에게 중국 연회에 초대된 경험을 이야기합니다. #Person2#는 젓가락을 밥그릇에 꽂거나 향 두 개를 닮아 불길하게 느낀다고 말합니다.
# ===================
#  Mary와 Frank는 서로 좋아하는 영화 장르에 대해 이야기한다. 그들은 동네 영화 대여점에 가서 영화를 빌리기로 결정한다.
# Mary와 Frank는 서로 좋아하는 영화 장르에 대해 이야기한다. 그들은 동네 영화 대여점에 가서 영화를 빌리기로 결정한다.
# ===================
#  #Person1#은 #Person2#에게 녹색당에 가입할 의향이 있는지 묻습니다. #Person2#는 녹색당이 선거에서 이길 가능성은 없다고 생각하지만, 작은 정치 단체나 압력 단체도 큰 정당에 영향을 미칠 수 있다고 말합니다.
# #Person1#은 #Person2#에게 녹색당에 가입할 의향이 있는지 묻습니다. #Person2#는 녹색당이 선거에서 이길 가능성은 없다고 생각하지만, 작은 정치 단체나 압력 단체도 큰 정당에 영향을 미칠 수 있다고 말합니다.
# ===================
#  Wilson 씨는 상품 문제로 인해 사과하고 #Person1#에게 책임을 묻겠다고 약속합니다.
# Wilson 씨는 상품 문제로 인해 사과하고 #Person1#에게 책임을 묻겠다고 약속합니다.
# ===================
#  #Person2#는 #Person1#에게 강도 사건을 목격했다고 말합니다. #Person2#는 경찰서에 와달라고 요청합니다.
# #Person2#는 #Person1#에게 강도 사건을 목격했다고 말합니다. #Person2#는 경찰서에 와달라고 요청합니다.
# ===================
#  #Person1#은 #Person2#에게 아빠와 엄마가 데이트를 위해 저녁을 먹으러 갔다고 말한다. #Person2#는 피자를 주문하고 싶어 한다.
# #Person1#은 #Person2#에게 아빠와 엄마가 데이트를 위해 저녁을 먹으러 갔다고 말한다. #Person2#는 피자를 주문하고 싶어 한다.
# ===================
#  #Person1#은 새해 결심으로 다이어트를 하기로 했습니다. #Person2#는 #Person1#에게 다이어트를 통해 정크푸드를 끊고 과자도 없고 튀긴 음식을 먹지 않을 것이라고 말합니다.
# #Person1#은 새해 결심으로 다이어트를 하기로 했습니다. #Person2#는 #Person1#에게 다이어트를 통해 정크푸드를 끊고 과자도 없고 튀긴 음식을 먹지 않을 것이라고 말합니다.
# ===================
#  Karen Huang은 터치톤 등록 시스템을 통해 Comp Lit 287 수업을 등록하려 했으나, 컴퓨터 승인 문제로 이미 만원이 되었습니다. #Person1#은 Karen이 해당 수업을 수강할 수 있도록 도와주고, Cohen 교수님의 도움으로 추가 자리를 저장할 수 있는 특별 코드를 제공합니다.
# Karen Huang은 터치톤 등록 시스템을 통해 Comp Lit 287 수업을 등록하려 했으나, 컴퓨터 승인 문제로 이미 만원이 되었습니다. #Person1#은 Karen이 해당 수업을 수강할 수 있도록 도와주고, Cohen 교수님의 도움으로 추가 자리를 저장할 수 있는 특별 코드를 제공합니다.
# ===================
#  #Person1#과 #Person2#는 우산을 쓰고 함께 걸어서 가든 호텔로 향하고 있습니다.
# #Person1#과 #Person2#는 우산을 쓰고 함께 걸어서 가든 호텔로 향하고 있습니다.
# ===================
#  Daisy가 Jack을 태워주기로 했습니다. 그들은 고속도로에서 좋은 선택을 했습니다.
# Daisy가 Jack을 태워주기로 했습니다. 그들은 고속도로에서 좋은 선택을 했습니다.
# ===================
#  #Person2#는 #Person1#에게 큰불이 밤에 일어났다고 설명합니다.
# #Person2#는 #Person1#에게 큰불이 밤에 일어났다고 설명합니다.
# ===================
#  #Person1#은 #Person2#에게 900위안을 현금으로 계산해 달라고 요청합니다. #Person2#는 신용카드로 결제하고 영수증을 제출합니다.
# #Person1#은 #Person2#에게 900위안을 현금으로 계산해 달라고 요청합니다. #Person2#는 신용카드로 결제하고 영수증을 제출합니다.
# ===================
#  #Person2#는 #Person1#의 차를 세차하고 싶어합니다. #Person1#은 샴푸와 진공청소기를 사용하여 차량 외부를 세차하고, 창문을 닦아줍니다.
# #Person2#는 #Person1#의 차를 세차하고 싶어합니다. #Person1#은 샴푸와 진공청소기를 사용하여 차량 외부를 세차하고, 창문을 닦아줍니다.
# ===================
#  해리는 아내가 이집트로 가고 싶어 해외여행을 고려 중이다. 해리는 배로 갈지, 비행기로 갈지 고민하고 있다. #Person1#은 해리에게 걱정 문제를 해결하면 여행을 갈 수 있다고 조언한다.
# 해리는 아내가 이집트로 가고 싶어 해외여행을 고려 중이다. 해리는 배로 갈지, 비행기로 갈지 고민하고 있다. #Person1#은 해리에게 걱정 문제를 해결하면 여행을 갈 수 있다고 조언한다.
# ===================
#  Johnson은 새로운 회원으로부터 기계에 대한 몇 가지 조언을 받습니다. 그는 스트레칭을 하고 기계를 워밍업하며, 각 기계의 진도를 추적할 수 있도록 체크인하고, 기계에 적합한 시작 무게를 정해줍니다. #Person1#은 지쳤다고 느끼면 중단하라고 조언합니다.
# Johnson은 새로운 회원으로부터 기계에 대한 몇 가지 조언을 받습니다. 그는 스트레칭을 하고 기계를 워밍업하며, 각 기계의 진도를 추적할 수 있도록 체크인하고, 기계에 적합한 시작 무게를 정해줍니다. #Person1#은 지쳤다고 느끼면 중단하라고 조언합니다.
# ===================
#  #Person2#는 회사가 문을 닫아 실직 상태이며, #Person1#과 #Person2#는 먹고 살 정도의 일을 원합니다. 그들은 전기 기술자 프로그램에 지원할 계획입니다.
# #Person2#는 회사가 문을 닫아 실직 상태이며, #Person1#과 #Person2#는 먹고 살 정도의 일을 원합니다. 그들은 전기 기술자 프로그램에 지원할 계획입니다.
# ===================
#  #Person2#는 #Person1#에게 강아지 밥과 목욕 서비스를 제공하고, 토요일에 수의사 예약을 상기시킵니다.
# #Person2#는 #Person1#에게 강아지 밥과 목욕 서비스를 제공하고, 토요일에 수의사 예약을 상기시킵니다.
# ===================
#  에이든은 집주인 아주머니께 200달러 빚이 있어 #Person1#에게 월요일에 돈을 빌려달라고 부탁한다. #Person1#은 #Person2#에게 오늘 저녁에 저녁을 먹자고 제안한다.
# 에이든은 집주인 아주머니께 200달러 빚이 있어 #Person1#에게 월요일에 돈을 빌려달라고 부탁한다. #Person1#은 #Person2#에게 오늘 저녁에 저녁을 먹자고 제안한다.
# ===================
#  #Person2#는 두 달 동안 자선 단체에서 일한 경험이 #Person1#의 사고방식에 영향을 미쳤다고 생각합니다.
# #Person2#는 두 달 동안 자선 단체에서 일한 경험이 #Person1#의 사고방식에 영향을 미쳤다고 생각합니다.
# ===================
#  #Person2#는 #Person1#에게 전화나 이메일로 연락하여 약 일주일 후에 결과를 확인할 수 있다고 안내합니다.
# #Person2#는 #Person1#에게 전화나 이메일로 연락하여 약 일주일 후에 결과를 확인할 수 있다고 안내합니다.
# ===================
#  #Person1#이 #Person2#에게 모우탄과 베이징 오리 구이를 추천합니다.
# #Person1#이 #Person2#에게 모우탄과 베이징 오리 구이를 추천합니다.
# ===================
#  Dan은 Angela에게 전화를 걸어 다음 주에 결혼한다고 알리고, Megan을 데리러 가기로 한다.
# Dan은 Angela에게 전화를 걸어 다음 주에 결혼한다고 알리고, Megan을 데리러 가기로 한다.
# ===================
#  #Person1#은 #Person2#에게 전통 그리스 요거트, 이탈리아 티라미수, 튀긴 바나나를 사다달라고 요청합니다. #Person2#는 이미 많이 먹어봤기 때문에 #Person1#이 먼저 먹어볼 것입니다.
# #Person1#은 #Person2#에게 전통 그리스 요거트, 이탈리아 티라미수, 튀긴 바나나를 사다달라고 요청합니다. #Person2#는 이미 많이 먹어봤기 때문에 #Person1#이 먼저 먹어볼 것입니다.
# ===================
#  Smith 씨는 #Person1#에게 예일 대학교, 경제학을 전공했으며, 지난 5년간 은행에서 일했고, 급여는 주당 500달러였습니다.
# Smith 씨는 #Person1#에게 예일 대학교, 경제학을 전공했으며, 지난 5년간 은행에서 일했고, 급여는 주당 500달러였습니다.
# ===================
#  #Person1#은 조카에게 줄 예쁜 선물로 디지털 바비를 구매하고 싶어 합니다. #Person2#는 카드로 32.42를 결제합니다.
# #Person1#은 조카에게 줄 예쁜 선물로 디지털 바비를 구매하고 싶어 합니다. #Person2#는 카드로 32.42를 결제합니다.
# ===================
#  #Person2#는 #Person1#의 도움으로 조던 운동화를 41 사이즈에 구매합니다.
# #Person2#는 #Person1#의 도움으로 조던 운동화를 41 사이즈에 구매합니다.
# ===================
#  #Person1#은 #Person2#에게 과학박물관에 가기 위해 4번 플랫폼에서 기차를 타고 State Street 역에서 내리라고 안내합니다.
# #Person1#은 #Person2#에게 과학박물관에 가기 위해 4번 플랫폼에서 기차를 타고 State Street 역에서 내리라고 안내합니다.
# ===================
#  사이먼은 #Person1#에게 단계적 은퇴 제도와 구인 정보를 게시하는 시스템에 대해 설명합니다. 그는 6개월 동안 일을 쉬었고, 그 후 이전의 회사에서 프로젝트 업무에 지원할 수 있게 되었습니다. 회사도 유연성을 얻을 수 있으며, 이전 직장 인맥이 회사를 좋게 만든다고 생각합니다.
# 사이먼은 #Person1#에게 단계적 은퇴 제도와 구인 정보를 게시하는 시스템에 대해 설명합니다. 그는 6개월 동안 일을 쉬었고, 그 후 이전의 회사에서 프로젝트 업무에 지원할 수 있게 되었습니다. 회사도 유연성을 얻을 수 있으며, 이전 직장 인맥이 회사를 좋게 만든다고 생각합니다.
# ===================
#  Rocky는 #Person1#에게 파티에 가자고 제안하지만, #Person1#은 외향적이고 다정하며 사람 차별하지 않는 여자를 선호한다고 말한다. #Person2#는 Rusty에게 안부 전하라고 한다.
# Rocky는 #Person1#에게 파티에 가자고 제안하지만, #Person1#은 외향적이고 다정하며 사람 차별하지 않는 여자를 선호한다고 말한다. #Person2#는 Rusty에게 안부 전하라고 한다.
# ===================
#  #Person1#과 #Person2#는 어젯밤 폭풍으로 창문 몇 개가 부서졌고, 큰 나무 하나가 부러졌습니다. #Person1#은 날씨가 끔찍하다고 느낍니다.
# #Person1#과 #Person2#는 어젯밤 폭풍으로 창문 몇 개가 부서졌고, 큰 나무 하나가 부러졌습니다. #Person1#은 날씨가 끔찍하다고 느낍니다.
# ===================
#  #Person1#은 #Person2#에게 TV 시청이 지루하다고 말합니다. #Person2#는 나가서 노는 것이 더 좋다고 생각하지만, #Person1#은 음악 같이 하는 것을 제안합니다.
# #Person1#은 #Person2#에게 TV 시청이 지루하다고 말합니다. #Person2#는 나가서 노는 것이 더 좋다고 생각하지만, #Person1#은 음악 같이 하는 것을 제안합니다.
# ===================
#  Ben은 #Person1#에게 새 학교에서의 첫 수업 시간과 쉬는 시간, 그리고 점심시간에 대해 설명합니다. #Person1#은 Ben에게 쉬는 시간에 먹을 것을 살 수 있다고 제안합니다.
# Ben은 #Person1#에게 새 학교에서의 첫 수업 시간과 쉬는 시간, 그리고 점심시간에 대해 설명합니다. #Person1#은 Ben에게 쉬는 시간에 먹을 것을 살 수 있다고 제안합니다.
# ===================
#  Adam은 무릎 상태가 나아졌습니다. #Person1#은 Adam에게 쉬고 경기 영상을 보라고 제안하며, 3일 안에 회복되기를 바라고 있습니다.
# Adam은 무릎 상태가 나아졌습니다. #Person1#은 Adam에게 쉬고 경기 영상을 보라고 제안하며, 3일 안에 회복되기를 바라고 있습니다.
# ===================
#  #Person2#는 프린터가 고장 나서 #Person1#에게 도움을 요청합니다.
# #Person2#는 프린터가 고장 나서 #Person1#에게 도움을 요청합니다.
# ===================
#  #Person1#이 커튼을 달기 위해 #Person2#에게 도움을 요청합니다.
# #Person1#이 커튼을 달기 위해 #Person2#에게 도움을 요청합니다.
# ===================
#  #Person1#은 Jack에게 주말 캠핑 계획을 확인하기 위해 달력을 확인해줄 것을 요청합니다.
# #Person1#은 Jack에게 주말 캠핑 계획을 확인하기 위해 달력을 확인해줄 것을 요청합니다.
# ===================
#  #Person1#은 #Person2#에게 임신 사실을 알립니다. #Person2#는 #Person1#의 임신 사실을 알고 기뻐합니다.
# #Person1#은 #Person2#에게 임신 사실을 알립니다. #Person2#는 #Person1#의 임신 사실을 알고 기뻐합니다.
# ===================
#  #Person2#는 딸이 대학 결정을 못 하고 있어 걱정하고 있습니다. #Person1#은 #Person2#에게 조언을 해주고 싶다고 말합니다.
# #Person2#는 딸이 대학 결정을 못 하고 있어 걱정하고 있습니다. #Person1#은 #Person2#에게 조언을 해주고 싶다고 말합니다.
# ===================
#  #Person1#은 #Person2#에게 한 번의 실수로 일자리를 잃으면 생계 유지에 어려움을 겪을 것이라고 말합니다. #Person2#는 #Person1#에게 다른 일자리를 찾아 함께 살자고 제안합니다.
# #Person1#은 #Person2#에게 한 번의 실수로 일자리를 잃으면 생계 유지에 어려움을 겪을 것이라고 말합니다. #Person2#는 #Person1#에게 다른 일자리를 찾아 함께 살자고 제안합니다.
# ===================
#  #Person2#는 #Person1#에게 에딘버러 대학의 박사과정 학생인 #Person1#을 초대하여 재미있게 놀고 강연도 함께 하자고 제안합니다.
# #Person2#는 #Person1#에게 에딘버러 대학의 박사과정 학생인 #Person1#을 초대하여 재미있게 놀고 강연도 함께 하자고 제안합니다.
# ===================
#  #Person1#은 #Person2#에게 John네 집에 가자고 제안하지만, #Person2#는 감기에 걸려 집에서 쉬라고 조언한다.
# #Person1#은 #Person2#에게 John네 집에 가자고 제안하지만, #Person2#는 감기에 걸려 집에서 쉬라고 조언한다.
# ===================
#  Mr. Faber는 요크 호텔에 전화하여 3박 동안 더블 룸을 예약합니다.
# Mr. Faber는 요크 호텔에 전화하여 3박 동안 더블 룸을 예약합니다.
# ===================
#  #Person2#는 웨스트 더비를 추천하지만, #Person1#은 플랫을 선호합니다. #Person2#는 친구 John Godfrey에게 일요일 10일까지 연락하라고 조언합니다.
# #Person2#는 웨스트 더비를 추천하지만, #Person1#은 플랫을 선호합니다. #Person2#는 친구 John Godfrey에게 일요일 10일까지 연락하라고 조언합니다.
# ===================
#  #Person1#은 #Person2#에게 잘못된 길을 안내한 경찰관에게 돈을 주려 하지 않았다면 이런 일이 발생하지 않았을 것이라고 비난합니다.
# #Person1#은 #Person2#에게 잘못된 길을 안내한 경찰관에게 돈을 주려 하지 않았다면 이런 일이 발생하지 않았을 것이라고 비난합니다.
# ===================
#  Dan은 9월 10일 전화로 100대 컴퓨터 주문 건에 대해 확인하려고 전화했으나 인력이 부족하여 2일 지연되었습니다. Darlene은 Dan에게 전화해 상황을 전달할 것입니다.
# Dan은 9월 10일 전화로 100대 컴퓨터 주문 건에 대해 확인하려고 전화했으나 인력이 부족하여 2일 지연되었습니다. Darlene은 Dan에게 전화해 상황을 전달할 것입니다.
# ===================
#  #Person1#은 #Person2#에게 워싱턴 포스트 신문의 사본을 제공합니다. 워싱턴 포스트 신문은 1877년 12월에 Stilson Hutchins가 창간되었고, 뉴욕 포스트 신문은 1881년 12월에 창간되었습니다.
# #Person1#은 #Person2#에게 워싱턴 포스트 신문의 사본을 제공합니다. 워싱턴 포스트 신문은 1877년 12월에 Stilson Hutchins가 창간되었고, 뉴욕 포스트 신문은 1881년 12월에 창간되었습니다.
# ===================
#  #Person2#의 컴퓨터가 이메일 용량을 초과하여 이메일을 보낼 수 없게 되었습니다. #Person1#은 #Person2#에게 파일을 압축해서 보내라고 조언합니다.
# #Person2#의 컴퓨터가 이메일 용량을 초과하여 이메일을 보낼 수 없게 되었습니다. #Person1#은 #Person2#에게 파일을 압축해서 보내라고 조언합니다.
# ===================
#  #Person2#는 주말에 #Person1#을 초대해 주셔서 감사하다고 말합니다.
# #Person2#는 주말에 #Person1#을 초대해 주셔서 감사하다고 말합니다.
# ===================
#  #Person1#과 중국 음식을 먹고 싶어 하고, #Person2#는 Panda Express에서 중국 음식을 사 먹기로 결정한다.
# #Person1#과 중국 음식을 먹고 싶어 하고, #Person2#는 Panda Express에서 중국 음식을 사 먹기로 결정한다.
# ===================
#  메리는 Hans 가구 매장에 영업직을 제안했으나 다른 후보자가 더 많은 경험이 있어 다시 고려하기로 했습니다.
# 메리는 Hans 가구 매장에 영업직을 제안했으나 다른 후보자가 더 많은 경험이 있어 다시 고려하기로 했습니다.
# ===================
#  #Person1#이 #Person2#에게 열 번째 전화를 걸었습니다. #Person2#는 경찰에 신고할 것입니다.
# #Person1#이 #Person2#에게 열 번째 전화를 걸었습니다. #Person2#는 경찰에 신고할 것입니다.
# ===================
#  #Person2#는 음악 교사가 되고 싶어 합니다. #Person1#은 음악과 예술에서 학사와 석사 학위를 가지고 있으며, 다양한 장르의 음악을 즐깁니다. #Person2#는 클래식 음악이 사람의 감정과 성격에 미치는 영향을 설명하고, 클래식 음악을 듣는 것이 스트레스를 해소하는 데 도움이 된다고 언급합니다. #Person1#의 경력에 만족하며 클래식 음악을 들어보려 합니다.
# #Person2#는 음악 교사가 되고 싶어 합니다. #Person1#은 음악과 예술에서 학사와 석사 학위를 가지고 있으며, 다양한 장르의 음악을 즐깁니다. #Person2#는 클래식 음악이 사람의 감정과 성격에 미치는 영향을 설명하고, 클래식 음악을 듣는 것이 스트레스를 해소하는 데 도움이 된다고 언급합니다. #Person1#의 경력에 만족하며 클래식 음악을 들어보려 합니다.
# ===================
#  #Person1#은 #Person2#에게 같은 건물에 사는 미국 여자와 데이트 중이라고 말합니다. #Person2#는 곧 #Person1#을 저녁에 초대할 계획입니다.
# #Person1#은 #Person2#에게 같은 건물에 사는 미국 여자와 데이트 중이라고 말합니다. #Person2#는 곧 #Person1#을 저녁에 초대할 계획입니다.
# ===================
#  #Person1#은 #Person2#에게 Mirella가 서부 해안 스타일에 영향을 받아 출근했다고 설명합니다. #Person2#는 캘리포니아의 작업 환경이 더 편하고 캐주얼하다고 생각하지만, 모두 하얀 셔츠에 짙은 색 양복과 넥타이를 매고 있어 이상하다고 생각합니다.
# #Person1#은 #Person2#에게 Mirella가 서부 해안 스타일에 영향을 받아 출근했다고 설명합니다. #Person2#는 캘리포니아의 작업 환경이 더 편하고 캐주얼하다고 생각하지만, 모두 하얀 셔츠에 짙은 색 양복과 넥타이를 매고 있어 이상하다고 생각합니다.
# ===================
#  #Person2#는 #Person1#의 법률 사무소를 열 계획이며, #Person1#은 #Person2#의 성공을 기원합니다.
# #Person2#는 #Person1#의 법률 사무소를 열 계획이며, #Person1#은 #Person2#의 성공을 기원합니다.
# ===================
#  Kate는 Peter에게 어젯밤에 온라인에서 네트워크 게임을 했다고 말합니다.
# Kate는 Peter에게 어젯밤에 온라인에서 네트워크 게임을 했다고 말합니다.
# ===================
#  #Person1#과 #Person2#는 배와 보트가 기차, 비행기 등 다른 교통수단에 자리를 내주고 있는 상황에 대해 이야기합니다.
# #Person1#과 #Person2#는 배와 보트가 기차, 비행기 등 다른 교통수단에 자리를 내주고 있는 상황에 대해 이야기합니다.
# ===================
#  Fanny와 Andy는 어젯밤에 악몽을 꿨고, 유령들이 그들을 쫓아왔으며, 엄마가 깨워 도움을 요청했다고 이야기합니다. Anny는 미시간 대학교에 들어갈까 봐 겁납니다.
# Fanny와 Andy는 어젯밤에 악몽을 꿨고, 유령들이 그들을 쫓아왔으며, 엄마가 깨워 도움을 요청했다고 이야기합니다. Anny는 미시간 대학교에 들어갈까 봐 겁납니다.
# ===================
#  #Person1#과 Ernie는 밴드를 시작하고 Vanilla Ice 노래에 대해 이야기합니다.
# #Person1#과 Ernie는 밴드를 시작하고 Vanilla Ice 노래에 대해 이야기합니다.
# ===================
#  #Person1#은 #Person2#에게 뉴올리언스로 여행 왔다고 말하고, 강변 저녁 유람선 투어를 제안합니다. #Person2#는 Sanger Theater에서 열리는 쇼를 기대하고 있습니다.
# #Person1#은 #Person2#에게 뉴올리언스로 여행 왔다고 말하고, 강변 저녁 유람선 투어를 제안합니다. #Person2#는 Sanger Theater에서 열리는 쇼를 기대하고 있습니다.
# ===================
#  #Person1#은 사이즈가 마음에 들어 #Person2#의 신용카드로 구매합니다.
# #Person1#은 사이즈가 마음에 들어 #Person2#의 신용카드로 구매합니다.
# ===================
#  Blake씨가 Foster에게 교육 매뉴얼을 내일 오후에 그의 사무실에 가져다줄 예정입니다.
# Blake씨가 Foster에게 교육 매뉴얼을 내일 오후에 그의 사무실에 가져다줄 예정입니다.
# ===================
#  #Person2#는 #Person1#에게 이번 휴가 동안 롱아일랜드를 출발하여 솔트레이크시티까지 차로 이동하여 마흔 번째 생일을 축하할 예정이며, 호텔에서 묵고 지나는 길에 현지 음식을 즐길 것이라고 말합니다.
# #Person2#는 #Person1#에게 이번 휴가 동안 롱아일랜드를 출발하여 솔트레이크시티까지 차로 이동하여 마흔 번째 생일을 축하할 예정이며, 호텔에서 묵고 지나는 길에 현지 음식을 즐길 것이라고 말합니다.
# ===================
#  #Person1#은 #Person2#에게 파멜라의 비행기를 지금 타라고 재촉합니다. #Person2#는 파멜라가 아프지 않도록 돌봐 달라고 부탁하고, #Person1#은 파멜라에게 편지를 쓸 것이라고 전해달라고 합니다.
# #Person1#은 #Person2#에게 파멜라의 비행기를 지금 타라고 재촉합니다. #Person2#는 파멜라가 아프지 않도록 돌봐 달라고 부탁하고, #Person1#은 파멜라에게 편지를 쓸 것이라고 전해달라고 합니다.
# ===================
#  #Person1#은 #Person2#에게 77번 도로를 걸어서 걸어서 갈 수 있는 번화한 거리를 안내합니다.
# #Person1#은 #Person2#에게 77번 도로를 걸어서 걸어서 갈 수 있는 번화한 거리를 안내합니다.
# ===================
#  #Person2#는 #Person1#에게 메카로 성지순례 가는 무슬림들을 소개합니다. #Person1#은 무슬림이 평생 최소한 한 번은 하즈를 가야 한다고 믿기 때문에 매년 많은 사람들이 하즈를 간다고 설명합니다.
# #Person2#는 #Person1#에게 메카로 성지순례 가는 무슬림들을 소개합니다. #Person1#은 무슬림이 평생 최소한 한 번은 하즈를 가야 한다고 믿기 때문에 매년 많은 사람들이 하즈를 간다고 설명합니다.
# ===================
#  #Person1#이 #Person2#에게 중앙 백화점으로 가는 길을 안내합니다.
# #Person1#이 #Person2#에게 중앙 백화점으로 가는 길을 안내합니다.
# ===================
#  #Person1#은 #Person2#에게 다음 주 동안 런던에 함께 가자고 제안합니다. #Person2#는 기차를 선호하고, #Person1#은 자동차를 선호합니다.
# #Person1#은 #Person2#에게 다음 주 동안 런던에 함께 가자고 제안합니다. #Person2#는 기차를 선호하고, #Person1#은 자동차를 선호합니다.
# ===================
#  케서린과 톰은 점심을 잘 먹지 못했다. 케서린은 패스트푸드가 건강에 좋지 않다고 생각하고, 톰은 미국인의 3분의 2가 그런 곳을 피한다고 말한다.
# 케서린과 톰은 점심을 잘 먹지 못했다. 케서린은 패스트푸드가 건강에 좋지 않다고 생각하고, 톰은 미국인의 3분의 2가 그런 곳을 피한다고 말한다.
# ===================
#  #Person1#은 #Person2#에게 레모네이드, 바비큐 윙, 베이비 백 립을 추가로 주문합니다.
# #Person1#은 #Person2#에게 레모네이드, 바비큐 윙, 베이비 백 립을 추가로 주문합니다.
# ===================
#  #Person2#가 #Person1#의 도움으로 더블 치즈버거와 감자튀김, 컬리프라이, 중간 사이즈 펩시를 주문합니다.
# #Person2#가 #Person1#의 도움으로 더블 치즈버거와 감자튀김, 컬리프라이, 중간 사이즈 펩시를 주문합니다.
# ===================
#  #Person1#은 #Person2#에게 반숙 계란과 프라이드 에그를 추천하지만, #Person2#는 부드럽게 끓인 계란을 선호합니다.
# #Person1#은 #Person2#에게 반숙 계란과 프라이드 에그를 추천하지만, #Person2#는 부드럽게 끓인 계란을 선호합니다.
# ===================
#  #Person2#는 #Person1#에게 그랜드 호텔로 가라고 안내합니다.
# #Person2#는 #Person1#에게 그랜드 호텔로 가라고 안내합니다.
# ===================
#  #Person2#는 아이들에게 미국 경찰의 외모에 대해 보여주고 싶어 사진을 찍습니다.
# #Person2#는 아이들에게 미국 경찰의 외모에 대해 보여주고 싶어 사진을 찍습니다.
# ===================
#  #Person2#가 #Person1#에게 내일 빈 방이 없다고 알립니다. #Person1#은 근처에 선셋 호텔을 추천합니다.
# #Person2#가 #Person1#에게 내일 빈 방이 없다고 알립니다. #Person1#은 근처에 선셋 호텔을 추천합니다.
# ===================
#  #Person2#는 미국 비자를 신청하기 위해 2주 전에 신청서를 제출했습니다. #Person1#은 많은 사람들이 서류를 올바르게 작성하지 않거나 필수 서류를 빠뜨려서 신청이 거절된다고 생각합니다.
# #Person2#는 미국 비자를 신청하기 위해 2주 전에 신청서를 제출했습니다. #Person1#은 많은 사람들이 서류를 올바르게 작성하지 않거나 필수 서류를 빠뜨려서 신청이 거절된다고 생각합니다.
# ===================
#  Anne은 펍에서 술 한잔하자고 제안하지만, #Person1#은 피곤해서 자야 한다고 답합니다.
# Anne은 펍에서 술 한잔하자고 제안하지만, #Person1#은 피곤해서 자야 한다고 답합니다.
# ===================
#  #Person1#은 Mary에게 인터넷 쇼핑이 편리하고 시간도 절약된다고 설명하며, 온라인 쇼핑을 통해 물건을 찾을 수 있다고 말합니다.
# #Person1#은 Mary에게 인터넷 쇼핑이 편리하고 시간도 절약된다고 설명하며, 온라인 쇼핑을 통해 물건을 찾을 수 있다고 말합니다.
# ===================
#  #Person2#는 #Person1#에게 미국식 회계에 익숙하지 않다고 설명합니다.
# #Person2#는 #Person1#에게 미국식 회계에 익숙하지 않다고 설명합니다.
# ===================
#  제인은 피터에게 시안에 가고 싶다고 말합니다. 피터는 여름에 시안을 방문할 계획이며, 제인은 하얼빈에 가고, 피터는 남서쪽을 선호합니다.
# 제인은 피터에게 시안에 가고 싶다고 말합니다. 피터는 여름에 시안을 방문할 계획이며, 제인은 하얼빈에 가고, 피터는 남서쪽을 선호합니다.
# ===================
#  #Person2#는 딸을 위해 로맨스 영화를 빌리려고 합니다. #Person1#은 #Person2#에게 비디오 대여를 추적하기 위해 발급하는 회원 양식을 작성해 달라고 요청합니다. #Person2#는 영화 대여비와 연체료를 제때 반납하라고 안내합니다.
# #Person2#는 딸을 위해 로맨스 영화를 빌리려고 합니다. #Person1#은 #Person2#에게 비디오 대여를 추적하기 위해 발급하는 회원 양식을 작성해 달라고 요청합니다. #Person2#는 영화 대여비와 연체료를 제때 반납하라고 안내합니다.
# ===================
#  #Person1#이 Mr. Lee에게 소포를 전달하기 위해 #Person2#에게 서명을 부탁합니다.
# #Person1#이 Mr. Lee에게 소포를 전달하기 위해 #Person2#에게 서명을 부탁합니다.
# ===================
#  #Person2#는 #Person1#에게 비행기가 내일 아침까지 출발하지 않는다고 알립니다. #Person1#은 #Person2#에게 공항 호텔에 방을 함께 사용해야 한다고 안내합니다.
# #Person2#는 #Person1#에게 비행기가 내일 아침까지 출발하지 않는다고 알립니다. #Person1#은 #Person2#에게 공항 호텔에 방을 함께 사용해야 한다고 안내합니다.
# ===================
#  #Person1#은 지난주에 컴퓨터 도움으로 보답했고, 이번에는 #Person2#가 대접하기로 했습니다.
# #Person1#은 지난주에 컴퓨터 도움으로 보답했고, 이번에는 #Person2#가 대접하기로 했습니다.
# ===================
#  #Person2#는 불면증으로 인해 잠을 잘 못 자고 있습니다. #Person1#은 #Person2#에게 요가 수업을 듣거나 이완 테크닉을 배우는 것이 스트레스 극복에 도움이 될 것이라고 조언합니다. #Person2#는 #Person1#에게 음악을 들어보라고 제안합니다.
# #Person2#는 불면증으로 인해 잠을 잘 못 자고 있습니다. #Person1#은 #Person2#에게 요가 수업을 듣거나 이완 테크닉을 배우는 것이 스트레스 극복에 도움이 될 것이라고 조언합니다. #Person2#는 #Person1#에게 음악을 들어보라고 제안합니다.
# ===================
#  #Person1#은 #Person2#에게 주방을 확 바꾸고 싶다고 말합니다.
# #Person1#은 #Person2#에게 주방을 확 바꾸고 싶다고 말합니다.
# ===================
#  Walter와 Sterling은 새 선생님에 대해 이야기한다.
# Walter와 Sterling은 새 선생님에 대해 이야기한다.
# ===================
#  #Person1#은 #Person2#의 검사 결과를 기다리고 있으며, #Person2#는 오늘 오후에 남편과 함께 방문할 예정입니다.
# #Person1#은 #Person2#의 검사 결과를 기다리고 있으며, #Person2#는 오늘 오후에 남편과 함께 방문할 예정입니다.
# ===================
#  Martin은 Eliza 선생님에게 시험 준비에 대한 감사를 표하고, Lamb 선생님이 그녀의 문제를 해결하는 데 도움을 준 것에 대해 감사를 표합니다.
# Martin은 Eliza 선생님에게 시험 준비에 대한 감사를 표하고, Lamb 선생님이 그녀의 문제를 해결하는 데 도움을 준 것에 대해 감사를 표합니다.
# ===================
#  #Person1#은 #Person2#의 도움으로 1등급보다 10일 더 저렴한 소포를 한국으로 보내기로 결정합니다.
# #Person1#은 #Person2#의 도움으로 1등급보다 10일 더 저렴한 소포를 한국으로 보내기로 결정합니다.
# ===================
#  #Person1#은 호텔 방 어디에도 휴대폰이 없어 Linda에게 전화를 걸었습니다. #Person1#은 #Person2#에게 15분 후에 결혼식 준비를 위해 핸드폰을 가져가라고 제안합니다.
# #Person1#은 호텔 방 어디에도 휴대폰이 없어 Linda에게 전화를 걸었습니다. #Person1#은 #Person2#에게 15분 후에 결혼식 준비를 위해 핸드폰을 가져가라고 제안합니다.
# ===================
#  #Person2#는 #Person1#에게 서부의 항구 도시인 로스앤젤레스에서 왔다고 말합니다. #Person2#는 이틀 더 머무를 예정이며, #Person1#은 음료를 추가로 요청합니다.
# #Person2#는 #Person1#에게 서부의 항구 도시인 로스앤젤레스에서 왔다고 말합니다. #Person2#는 이틀 더 머무를 예정이며, #Person1#은 음료를 추가로 요청합니다.
# ===================
#  #Person1#은 여름 방학 동안 사업 수업을 듣고, 삼촌 회사에서 경험을 쌓을 계획이며, #Person2#는 미래에 대해 생각하지 않는다.
# #Person1#은 여름 방학 동안 사업 수업을 듣고, 삼촌 회사에서 경험을 쌓을 계획이며, #Person2#는 미래에 대해 생각하지 않는다.
# ===================
#  Mary는 우유를 배달하러 갔다가 12번 집의 정원 문이 잠겨 있는 것을 발견하고, 울타리를 넘어 문 쪽으로 가려고 했지만 개가 돌진하는 바람에 사고가 발생했다.
# Mary는 우유를 배달하러 갔다가 12번 집의 정원 문이 잠겨 있는 것을 발견하고, 울타리를 넘어 문 쪽으로 가려고 했지만 개가 돌진하는 바람에 사고가 발생했다.
# ===================
#  #Person1#은 #Person2#에게 회사에서 6년 동안 근무한 경험을 이야기합니다. #Person2#는 이전보다 더 오랜 시간을 일하고 새로운 기술을 개발하며 승진을 위한 준비를 마쳤다고 말합니다.
# #Person1#은 #Person2#에게 회사에서 6년 동안 근무한 경험을 이야기합니다. #Person2#는 이전보다 더 오랜 시간을 일하고 새로운 기술을 개발하며 승진을 위한 준비를 마쳤다고 말합니다.
# ===================
#  #Person2#는 #Person1#에게 보통 예금 통장에 이자가 없다고 설명하고, 은행에서 출금하거나 ATM에서 출금을 할 수 있다고 안내합니다.
# #Person2#는 #Person1#에게 보통 예금 통장에 이자가 없다고 설명하고, 은행에서 출금하거나 ATM에서 출금을 할 수 있다고 안내합니다.
# ===================
#  #Person1#은 처음으로 중국에 와서 중국 음식을 먹어보고 싶어 한다. #Person2#는 #Person1#에게 베이징 요리와 전취덕 식당을 추천한다.
# #Person1#은 처음으로 중국에 와서 중국 음식을 먹어보고 싶어 한다. #Person2#는 #Person1#에게 베이징 요리와 전취덕 식당을 추천한다.
# ===================
#  #Person2#는 양털 배송이 늦어질까 봐 걱정하고 있습니다. #Person1#은 #Person2#에게 오클랜드에서 첫 번째 배에 주문을 실어주기로 했습니다.
# #Person2#는 양털 배송이 늦어질까 봐 걱정하고 있습니다. #Person1#은 #Person2#에게 오클랜드에서 첫 번째 배에 주문을 실어주기로 했습니다.
# ===================
#  #Person2#가 방에서 독서등을 깨뜨려 변상하기 위해 #Person1#에게 양식을 작성해 달라고 요청합니다.
# #Person2#가 방에서 독서등을 깨뜨려 변상하기 위해 #Person1#에게 양식을 작성해 달라고 요청합니다.
# ===================
#  #Person1#은 #Person2#에게 2006 회계연도 마케팅 계획에 대해 설명합니다. #Person2#는 해외 시장에서의 유통을 두 배로 늘리는 목표를 세웠으며, 시장의 원래 상태, 시장의 상태, 마케팅 수단, 올해의 최종 판매 수치를 고려해야 한다고 설명합니다.
# #Person1#은 #Person2#에게 2006 회계연도 마케팅 계획에 대해 설명합니다. #Person2#는 해외 시장에서의 유통을 두 배로 늘리는 목표를 세웠으며, 시장의 원래 상태, 시장의 상태, 마케팅 수단, 올해의 최종 판매 수치를 고려해야 한다고 설명합니다.
# ===================
#  #Person2#는 #Person1#에게 휴가 계획에 대해 설명합니다. #Person2#는 파리에서 출발하여 밀라노로 가고, 에든버러에서 페스티벌에 참석할 예정입니다.
# #Person2#는 #Person1#에게 휴가 계획에 대해 설명합니다. #Person2#는 파리에서 출발하여 밀라노로 가고, 에든버러에서 페스티벌에 참석할 예정입니다.
# ===================
#  Jimmy Fox는 중형차를 예약했으나, #Person1#은 예약을 유지하는 것이 중요하다고 설명합니다. #Person2#는 작은 차로 예약을 변경하고 보험과 대여료에 대해 할인을 제공합니다.
# Jimmy Fox는 중형차를 예약했으나, #Person1#은 예약을 유지하는 것이 중요하다고 설명합니다. #Person2#는 작은 차로 예약을 변경하고 보험과 대여료에 대해 할인을 제공합니다.
# ===================
#  #Person1#은 #Person2#에게 카드게임을 하라고 하지만, #Person2#는 숙제를 다 끝냈으니 소리내지 말라고 경고합니다.
# #Person1#은 #Person2#에게 카드게임을 하라고 하지만, #Person2#는 숙제를 다 끝냈으니 소리내지 말라고 경고합니다.
# ===================
#  Ann은 Mr. Jones에게 이번 주 회계사와 회의, Ms. Von과의 대화 시간을 안내합니다.
# Ann은 Mr. Jones에게 이번 주 회계사와 회의, Ms. Von과의 대화 시간을 안내합니다.
# ===================
#  #Person2#는 세계 지도를 보고 있으며, #Person1#에게 세계 대부분이 물로 덮여 있다고 설명합니다. #Person1#은 #Person2#의 지도를 흥미롭게 여기며, 인터넷에서 더 많은 정보를 찾아보겠다고 합니다.
# #Person2#는 세계 지도를 보고 있으며, #Person1#에게 세계 대부분이 물로 덮여 있다고 설명합니다. #Person1#은 #Person2#의 지도를 흥미롭게 여기며, 인터넷에서 더 많은 정보를 찾아보겠다고 합니다.
# ===================
#  #Person2#는 금연 방을 예약했으나 흡연 냄새로 인해 방을 변경해야 했습니다. #Person1#은 #Person2#에게 금연 방을 마련해 줍니다.
# #Person2#는 금연 방을 예약했으나 흡연 냄새로 인해 방을 변경해야 했습니다. #Person1#은 #Person2#에게 금연 방을 마련해 줍니다.
# ===================
#  #Person1#은 Bill에게 젖어 있는 페인트에 손을 대지 말라고 주의를 주지만, Bill은 John Sampson만큼 부주의하지는 않았다고 주장합니다.
# ...
# Paula는 세 들어 사는 집의 집주인 Ms. Connors가 고장 난 식기세척기를 수리하고 비용을 월세에서 공제했지만, 집주인이 월세를 전액 납부하지 않아 문제가 발생했다고 설명합니다. Paula가 이를 도와주기로 했습니다.
# ===================
#  #Person1#과 에어컨이 고장 나 에어컨 수리공을 고용해야 합니다. #Person2#는 Dan에게 화장실 변기와 전기 배선 고치는 일을 맡기라고 제안합니다.
# #Person1#과 에어컨이 고장 나 에어컨 수리공을 고용해야 합니다. #Person2#는 Dan에게 화장실 변기와 전기 배선 고치는 일을 맡기라고 제안합니다.
# ===================
#  #Person2#는 해고당했고, #Person1#은 대출금을 낼 수 있는 일을 찾고 있습니다. #Person2#는 전기공 견습생 프로그램 공고에서 좋은 인상을 받았습니다.
# #Person2#는 해고당했고, #Person1#은 대출금을 낼 수 있는 일을 찾고 있습니다. #Person2#는 전기공 견습생 프로그램 공고에서 좋은 인상을 받았습니다.
# ===================
#  #Person2#는 #Person1#에게 사장님의 장점과 강점에 대해 설명합니다.
# #Person2#는 #Person1#에게 사장님의 장점과 강점에 대해 설명합니다.
# ===================
#  Tang 씨는 Youth International Travel Agency에서 일하고 있으며, 영어와 러시아어 두 가지 언어를 구사합니다.
# Tang 씨는 Youth International Travel Agency에서 일하고 있으며, 영어와 러시아어 두 가지 언어를 구사합니다.
# ===================
#  #Person2#가 #Person1#의 도움으로 금 시계를 구매합니다.
# #Person2#가 #Person1#의 도움으로 금 시계를 구매합니다.
# ===================
#  Tom은 Sara에게 딸 Maria가 열이 나서 병원에 데려갈 예정이며, Ken은 아직 저녁을 먹지 못했다고 알립니다.
# Tom은 Sara에게 딸 Maria가 열이 나서 병원에 데려갈 예정이며, Ken은 아직 저녁을 먹지 못했다고 알립니다.
# ===================
#  Amy는 #Person1#에게 첫 직장이 총지배인 비서로 시작하여 인사부장으로 승진했으며, 현재는 인사부장에서 일하고 있다고 말합니다.
# Amy는 #Person1#에게 첫 직장이 총지배인 비서로 시작하여 인사부장으로 승진했으며, 현재는 인사부장에서 일하고 있다고 말합니다.
# ===================
#  Andrew는 #Person1#에게 자신의 체중을 감량하기 위해 운동을 해야 한다고 말합니다. #Person1#은 #Person2#가 뚱뚱하지 않다고 생각하지만, #Person2#는 와후 다이어트를 통해 정보를 얻고 있다고 설명합니다.
# Andrew는 #Person1#에게 자신의 체중을 감량하기 위해 운동을 해야 한다고 말합니다. #Person1#은 #Person2#가 뚱뚱하지 않다고 생각하지만, #Person2#는 와후 다이어트를 통해 정보를 얻고 있다고 설명합니다.
# ===================
#  메리가 브라운 컬리지의 그렉 손더스에게 전화하여 그녀의 대학 스포츠에 대해 문의합니다. 손더스 씨는 우수한 학점을 받았고, 고등학교에서 한 경기 최다 득점을 기록했습니다.
# 메리가 브라운 컬리지의 그렉 손더스에게 전화하여 그녀의 대학 스포츠에 대해 문의합니다. 손더스 씨는 우수한 학점을 받았고, 고등학교에서 한 경기 최다 득점을 기록했습니다.
# ===================
#  #Person2#는 기차역으로 가기 위해 택시를 타며, #Person1#은 #Person2#에게 기차역까지 약 20분이 걸린다고 설명합니다.
# #Person2#는 기차역으로 가기 위해 택시를 타며, #Person1#은 #Person2#에게 기차역까지 약 20분이 걸린다고 설명합니다.
# ===================
#  Brian은 #Person1#에게 대학에서 영어를 배웠다고 말하며, 라스베가스 여행에 대해 이야기합니다.
# Brian은 #Person1#에게 대학에서 영어를 배웠다고 말하며, 라스베가스 여행에 대해 이야기합니다.
# ===================
#  #Person2#는 연례 건강검진을 받으러 왔으며, #Person1#은 기본 검사와 알레르기 검사, 혈당 및 백혈구 수치를 검사할 예정입니다.
# #Person2#는 연례 건강검진을 받으러 왔으며, #Person1#은 기본 검사와 알레르기 검사, 혈당 및 백혈구 수치를 검사할 예정입니다.
# ===================
#  #Person1#은 복권에 당첨되면 전 세계를 여행할 계획이며, 월급 인상이 없을 것이라고 #Person2#에게 말합니다. #Person2#는 #Person1#이 밍크 코트를 사주기를 바라지만, #Person1#은 #Person2#가 스카치를 마실 자격이 있다고 생각합니다.
# #Person1#은 복권에 당첨되면 전 세계를 여행할 계획이며, 월급 인상이 없을 것이라고 #Person2#에게 말합니다. #Person2#는 #Person1#이 밍크 코트를 사주기를 바라지만, #Person1#은 #Person2#가 스카치를 마실 자격이 있다고 생각합니다.
# ===================
#  #Person1#은 #Person2#가 결혼하지 못할까 봐 무서워한다. #Person2#는 #Person1#에게 결혼 준비가 안 됐다고 말하며, #Person1#은 Amy가 위험에 빠질까 봐 두려워하지 말라고 조언한다.
# #Person1#은 #Person2#가 결혼하지 못할까 봐 무서워한다. #Person2#는 #Person1#에게 결혼 준비가 안 됐다고 말하며, #Person1#은 Amy가 위험에 빠질까 봐 두려워하지 말라고 조언한다.
# ===================
#  #Person1#은 #Person2#의 예전 명함과 동일한 서류를 인쇄하고 7일보다는 3일이 더 좋습니다.
# #Person1#은 #Person2#의 예전 명함과 동일한 서류를 인쇄하고 7일보다는 3일이 더 좋습니다.
# ===================
#  #Person1#은 브라이언에게 예약은 했지만 아직 확인할 것이 있다고 말합니다. 브라이언은 공항에서 전무님을 만나러 갈 예정이며, 회의는 정오에 시작됩니다.
# #Person1#은 브라이언에게 예약은 했지만 아직 확인할 것이 있다고 말합니다. 브라이언은 공항에서 전무님을 만나러 갈 예정이며, 회의는 정오에 시작됩니다.
# ===================
#  #Person1#은 Paul을 추수감사절 저녁 식사에 초대한다. 헤이는 부모님이 핀란드에 가신다고 걱정하고 있었으나, #Person1#의 도움으로 참석하게 되었다고 말한다. 그들은 음식을 준비하고, 파티에서 좋은 와인을 가져갈 예정이다.
# #Person1#은 Paul을 추수감사절 저녁 식사에 초대한다. 헤이는 부모님이 핀란드에 가신다고 걱정하고 있었으나, #Person1#의 도움으로 참석하게 되었다고 말한다. 그들은 음식을 준비하고, 파티에서 좋은 와인을 가져갈 예정이다.
# ===================
#  존은 이번 주말에 수잔에게 도움을 요청합니다. 수잔은 존에게 사촌과 함께 대학 캠퍼스를 방문하고 눈이 오면 집에 데려다주겠다고 제안합니다. 존은 눈보라가 오면 다시 작전을 짜보자고 제안합니다.
# 존은 이번 주말에 수잔에게 도움을 요청합니다. 수잔은 존에게 사촌과 함께 대학 캠퍼스를 방문하고 눈이 오면 집에 데려다주겠다고 제안합니다. 존은 눈보라가 오면 다시 작전을 짜보자고 제안합니다.
# ===================
#  #Person1#은 Ben에게 저녁 수업 정보를 요청했고, Ben은 사진 강좌, 홈페이지 디자인 초급 강의, 인도 요리, 그리고 저녁 파티를 제안했습니다.
# #Person1#은 Ben에게 저녁 수업 정보를 요청했고, Ben은 사진 강좌, 홈페이지 디자인 초급 강의, 인도 요리, 그리고 저녁 파티를 제안했습니다.
# ===================
#  #Person1#과 #Person2#는 저녁에 피자 익스피리언스와 킹피셔에서 점심을 먹기로 결정한다.
# #Person1#과 #Person2#는 저녁에 피자 익스피리언스와 킹피셔에서 점심을 먹기로 결정한다.
# ===================
#  Gene은 #Person1#에게 운전면허 시험에 참석하기 위해 로스앤젤레스에서 일하게 되었다고 말합니다. #Person1#은 Gene에게 운전 연습을 하고 시험에 합격하면 차를 살 계획이라고 이야기합니다.
# Gene은 #Person1#에게 운전면허 시험에 참석하기 위해 로스앤젤레스에서 일하게 되었다고 말합니다. #Person1#은 Gene에게 운전 연습을 하고 시험에 합격하면 차를 살 계획이라고 이야기합니다.
# ===================
#  #Person1#이 #Person2#에게 펜을 보여주고, #Person2#가 펜을 구매합니다.
# #Person1#이 #Person2#에게 펜을 보여주고, #Person2#가 펜을 구매합니다.
# ===================
#  #Person2#는 #Person1#에게 몇몇 경쟁사들과 재미로 파트너가 되어 미국 암 학회를 위한 마라톤을 후원한 경험을 이야기합니다. #Person2#는 기부금 모금이 좋은 일이라고 생각합니다.
# #Person2#는 #Person1#에게 몇몇 경쟁사들과 재미로 파트너가 되어 미국 암 학회를 위한 마라톤을 후원한 경험을 이야기합니다. #Person2#는 기부금 모금이 좋은 일이라고 생각합니다.
# ===================
#  #Person2#가 #Person1#에게 피크 트램까지 가는 길을 안내합니다.
# #Person2#가 #Person1#에게 피크 트램까지 가는 길을 안내합니다.
# ===================
#  #Person2#는 #Person1#의 도움으로 백단향 부채 두 개와 큰 것을 구매합니다.
# #Person2#는 #Person1#의 도움으로 백단향 부채 두 개와 큰 것을 구매합니다.
# ===================
#  #Person2#는 #Person1#에게 회사에 영향을 미치는 외부 요인은 정치적, 경제적, 사회적, 기술적 요소라고 설명합니다.
# #Person2#는 #Person1#에게 회사에 영향을 미치는 외부 요인은 정치적, 경제적, 사회적, 기술적 요소라고 설명합니다.
# ===================
#  #Person1#과 #Person2#는 오늘 오후 2시에 준비 회의를 시작할 예정입니다.
# #Person1#과 #Person2#는 오늘 오후 2시에 준비 회의를 시작할 예정입니다.
# ===================
#  #Person2#는 자연 경관과 문화적인 경관에 관심이 있어 #Person1#에게 짧은 여행을 추천합니다.
# #Person2#는 자연 경관과 문화적인 경관에 관심이 있어 #Person1#에게 짧은 여행을 추천합니다.
# ===================
#  #Person2#는 #Person1#의 도움으로 비프버거, 프렌치프라이, 밀크셰이크를 주문합니다.
# #Person2#는 #Person1#의 도움으로 비프버거, 프렌치프라이, 밀크셰이크를 주문합니다.
# ===================
#  #Person1#과 #Person2#는 등불 축제에 대해 이야기하고 있습니다. #Person1#은 #Person2#에게 큰 용 등불을 보여줍니다. 그들은 수수께끼를 풀기 위해 큰 등불을 보기로 합니다.
# #Person1#과 #Person2#는 등불 축제에 대해 이야기하고 있습니다. #Person1#은 #Person2#에게 큰 용 등불을 보여줍니다. 그들은 수수께끼를 풀기 위해 큰 등불을 보기로 합니다.
# ===================
#  Tina는 면접 첫 두 라운드를 성공적으로 통과하여 다음 주 월요일에 최종 라운드에 갈 수 있게 되었다. #Person1#은 그를 축하하기 위해 저녁에 카페에서 만나기로 했다.
# Tina는 면접 첫 두 라운드를 성공적으로 통과하여 다음 주 월요일에 최종 라운드에 갈 수 있게 되었다. #Person1#은 그를 축하하기 위해 저녁에 카페에서 만나기로 했다.
# ===================
#  팀이 카렌과 카렌을 다시 만나 인사를 나눈다.
# 팀이 카렌과 카렌을 다시 만나 인사를 나눈다.
# ===================
#  #Person1#과 #Person2#는 부서 회의에 참석하기 위해 문구, 복사기, 클라이언트들에 대해 논의합니다.
# #Person1#과 #Person2#는 부서 회의에 참석하기 위해 문구, 복사기, 클라이언트들에 대해 논의합니다.
# ===================
#  #Person1#은 목욕을 원하며 #Person2#에게 버튼 사용법과 스위치 사용법을 설명합니다.
# #Person1#은 목욕을 원하며 #Person2#에게 버튼 사용법과 스위치 사용법을 설명합니다.
# ===================
#  #Person1#이 #Person2#에게 베스트셀러 책과 최신작 추천을 요청합니다.
# #Person1#이 #Person2#에게 베스트셀러 책과 최신작 추천을 요청합니다.
# ===================
#  #Person2#는 #Person1#에게 #Person1#의 친구에게 읽기부터 시작해 천천히 익히라고 제안합니다. #Person1#은 #Person2#에게 저녁을 준비해 줍니다.
# #Person2#는 #Person1#에게 #Person1#의 친구에게 읽기부터 시작해 천천히 익히라고 제안합니다. #Person1#은 #Person2#에게 저녁을 준비해 줍니다.
# ===================
#  #Person1#은 #Person2#의 티켓을 예약하고 800달러를 카드로 결제합니다.
# #Person1#은 #Person2#의 티켓을 예약하고 800달러를 카드로 결제합니다.
# ===================
#  #Person2#는 #Person1#에게 냉동 피자를 만들어 보자고 제안하고, #Person1#은 #Person2#에게 건강한 요리 방법을 알려준다.
# #Person2#는 #Person1#에게 냉동 피자를 만들어 보자고 제안하고, #Person1#은 #Person2#에게 건강한 요리 방법을 알려준다.
# ===================
#  #Person2#는 #Person1#에게 부스에 있는 두 전화기가 어떻게 사용하는지 설명합니다. #Person1#은 수화기를 들고 신호를 기다린 후 번호를 누르고 동전을 투입구에 넣은 후 말하기 버튼을 누르면 통화가 가능하다고 설명합니다.
# #Person2#는 #Person1#에게 부스에 있는 두 전화기가 어떻게 사용하는지 설명합니다. #Person1#은 수화기를 들고 신호를 기다린 후 번호를 누르고 동전을 투입구에 넣은 후 말하기 버튼을 누르면 통화가 가능하다고 설명합니다.
# ===================
#  톰은 중고 컴퓨터를 사고 싶어 하며, #Person1#은 중고 물건이 새것만큼 좋다고 설명한다.
# 톰은 중고 컴퓨터를 사고 싶어 하며, #Person1#은 중고 물건이 새것만큼 좋다고 설명한다.
# ===================
#  Morgan은 #Person1#에게 중국 도시에서는 남은 음식을 폐기물 처리장에서 처리하며, 외식을 자주 하지 않기 때문에 남은 음식을 집에 가져가는 것이 더 낫다고 조언한다.
# Morgan은 #Person1#에게 중국 도시에서는 남은 음식을 폐기물 처리장에서 처리하며, 외식을 자주 하지 않기 때문에 남은 음식을 집에 가져가는 것이 더 낫다고 조언한다.
# ===================
#  해리가 해리에게 중국 길거리 시장에서 바가지를 쓴 경험을 이야기한다. 해리는 #Person1#에게 판매자가 흥정을 하지 않고 물건을 구매했다고 설명하며, 물건의 진짜 가치를 미리 알아보는 것이 중요하다고 조언한다.
# 해리가 해리에게 중국 길거리 시장에서 바가지를 쓴 경험을 이야기한다. 해리는 #Person1#에게 판매자가 흥정을 하지 않고 물건을 구매했다고 설명하며, 물건의 진짜 가치를 미리 알아보는 것이 중요하다고 조언한다.
# ===================
#  #Person2#는 #Person1#에게 회사 직원들은 영어를 잘해야 한다고 생각하며, 영어 말하기와 쓰기에 능숙하다고 설명합니다.
# #Person2#는 #Person1#에게 회사 직원들은 영어를 잘해야 한다고 생각하며, 영어 말하기와 쓰기에 능숙하다고 설명합니다.
# ===================
#  #Person2#는 새 계좌를 개설하고 싶어 합니다. #Person1#은 #Person2#에게 당좌예금과 저축예금을 동시에 개설할 수 있으며, 오버드래프트 최대 한도가 최대 1000이며 1 이자를 제공한다고 설명합니다.
# #Person2#는 새 계좌를 개설하고 싶어 합니다. #Person1#은 #Person2#에게 당좌예금과 저축예금을 동시에 개설할 수 있으며, 오버드래프트 최대 한도가 최대 1000이며 1 이자를 제공한다고 설명합니다.
# ===================
#  #Person2#는 #Person1#에게 특별 할인 쿠폰을 받을 수 있는 방법과 유효기간 내 사용할 수 있는 쿠폰을 설명합니다. #Person1#은 9봉지의 설탕을 구매하여 쿠폰 3장을 받습니다.
# #Person2#는 #Person1#에게 특별 할인 쿠폰을 받을 수 있는 방법과 유효기간 내 사용할 수 있는 쿠폰을 설명합니다. #Person1#은 9봉지의 설탕을 구매하여 쿠폰 3장을 받습니다.
# ===================
#  Mrs. Robinson이 Steve에게 Johnny의 부엌 청소를 도와달라고 요청합니다.
# Mrs. Robinson이 Steve에게 Johnny의 부엌 청소를 도와달라고 요청합니다.
# ===================
#  #Person2#는 상하이로 가는 기차표를 잃어버렸습니다. #Person1#은 #Person2#에게 소프트 슬리퍼를 추천하고, #Person2#는 지갑에 돈이 있는지 확인하려고 합니다.
# #Person2#는 상하이로 가는 기차표를 잃어버렸습니다. #Person1#은 #Person2#에게 소프트 슬리퍼를 추천하고, #Person2#는 지갑에 돈이 있는지 확인하려고 합니다.
# ===================
#  Ann은 #Person1#에게 다음 주에 뉴욕에 가기 위해 웰빙 인 더 에어 프로그램을 시도해보라고 조언합니다. Ann의 미국 여행은 바쁘고 시차 적응이 잘 안 되었습니다. #Person1#은 #Person2#에게 운동을 권장합니다.
# Ann은 #Person1#에게 다음 주에 뉴욕에 가기 위해 웰빙 인 더 에어 프로그램을 시도해보라고 조언합니다. Ann의 미국 여행은 바쁘고 시차 적응이 잘 안 되었습니다. #Person1#은 #Person2#에게 운동을 권장합니다.
# ===================
#  Tom은 John의 파티에 가고 싶어 하지만, Mary는 맥도날드에서 일하고 싶어 한다. Tom은 아버지 회사에서 여름 동안 일할 사람을 찾고 싶어 한다.
# Tom은 John의 파티에 가고 싶어 하지만, Mary는 맥도날드에서 일하고 싶어 한다. Tom은 아버지 회사에서 여름 동안 일할 사람을 찾고 싶어 한다.
# ===================
#  해리가 끔찍한 사고를 당했다. 해리는 #Person1#에게 자신이 겪은 끔찍한 경험을 이야기하며, 경찰이 처벌해야 한다고 주장한다.
# 해리가 끔찍한 사고를 당했다. 해리는 #Person1#에게 자신이 겪은 끔찍한 경험을 이야기하며, 경찰이 처벌해야 한다고 주장한다.
# ===================
#  #Person2#는 새로운 자전거 가게를 창업한 Steven Kayne 씨를 인터뷰합니다. 그는 경주용 자전거를 좋아하고 자전거 고치는 것을 좋아했습니다. 그는 사업을 시작할 때 돈이 모이면 바로 시작하려고 했으며, 은행 대출을 통해 사장이 되는 것이 좋겠다고 생각했습니다. 그는 자신의 가게의 운영 시간과 직원의 고용 여부, 그리고 자전거를 좋아하는 친구의 도움에 대해 설명합니다.
# #Person2#는 새로운 자전거 가게를 창업한 Steven Kayne 씨를 인터뷰합니다. 그는 경주용 자전거를 좋아하고 자전거 고치는 것을 좋아했습니다. 그는 사업을 시작할 때 돈이 모이면 바로 시작하려고 했으며, 은행 대출을 통해 사장이 되는 것이 좋겠다고 생각했습니다. 그는 자신의 가게의 운영 시간과 직원의 고용 여부, 그리고 자전거를 좋아하는 친구의 도움에 대해 설명합니다.
# ===================
#  #Person1#과 #Person2#는 좋은 중년 부부에 대해 이야기하고 있습니다. #Person1#은 #Person2#에게 중년은 인생의 가장자리에 있다고 말합니다.
# #Person1#과 #Person2#는 좋은 중년 부부에 대해 이야기하고 있습니다. #Person1#은 #Person2#에게 중년은 인생의 가장자리에 있다고 말합니다.
# ===================
#  #Person2#는 #Person1#에게 저녁으로 애플 크리스프, 초콜릿 무스 케이크, 두 번째 케이크를 주문하고, 커피와 차를 주문합니다.
# #Person2#는 #Person1#에게 저녁으로 애플 크리스프, 초콜릿 무스 케이크, 두 번째 케이크를 주문하고, 커피와 차를 주문합니다.
# ===================
#  #Person1#과 #Person2#는 아래층 침대를 원하며 동전을 던지기로 결정합니다. #Person1#은 #Person2#에게 창가 책상을 가져가라고 제안하고, #Person2#도 동의합니다. 그들은 서로의 책상을 함께 가져가기로 합니다.
# #Person1#과 #Person2#는 아래층 침대를 원하며 동전을 던지기로 결정합니다. #Person1#은 #Person2#에게 창가 책상을 가져가라고 제안하고, #Person2#도 동의합니다. 그들은 서로의 책상을 함께 가져가기로 합니다.
# ===================
#  Mr. Murray는 도서관 카드를 만들기 위해 신청서를 작성하고, 운영 시간과 제한 사항에 대해 안내받습니다.
# Mr. Murray는 도서관 카드를 만들기 위해 신청서를 작성하고, 운영 시간과 제한 사항에 대해 안내받습니다.
# ===================
#  #Person2#는 보통 9시부터 5시까지 일하고, 초과 근무 수당이나 보너스를 받지 않으며, 점심시간에는 커피 브레이크를 가질 수 있습니다. #Person1#은 칸막이 사무실에서 일하는 것을 좋아하지 않습니다.
# #Person2#는 보통 9시부터 5시까지 일하고, 초과 근무 수당이나 보너스를 받지 않으며, 점심시간에는 커피 브레이크를 가질 수 있습니다. #Person1#은 칸막이 사무실에서 일하는 것을 좋아하지 않습니다.
# ===================
#  Alice는 엄마에게 기계에 동전을 넣고, 기계에 비누를 넣는 방법을 알려줍니다. 엄마는 세탁을 처음 시작했다고 말하며, Alick은 엄마 역할을 해야 한다고 강조합니다.
# Alice는 엄마에게 기계에 동전을 넣고, 기계에 비누를 넣는 방법을 알려줍니다. 엄마는 세탁을 처음 시작했다고 말하며, Alick은 엄마 역할을 해야 한다고 강조합니다.
# ===================
#  #Person2#는 #Person1#에게 오늘 밤에 전화해달라고 부탁합니다.
# #Person2#는 #Person1#에게 오늘 밤에 전화해달라고 부탁합니다.
# ===================
#  Katie는 #Person1#에게 항상 일할 준비가 되어 있으며, 손님이 없을 때 직접 보석 닦고 거울 닦고, 캐셔기에 새 종이 넣고, 박스도 채우고 있다고 말합니다.
# Katie는 #Person1#에게 항상 일할 준비가 되어 있으며, 손님이 없을 때 직접 보석 닦고 거울 닦고, 캐셔기에 새 종이 넣고, 박스도 채우고 있다고 말합니다.
# ===================
#  #Person1#과 다음 주가 할아버지 생일이라 #Person2#는 집에서 깜짝 파티를 열 계획입니다. #Person1#은 피자, 할머니가 케이크, 샐러드, 스카프, 모자 등을 준비할 예정입니다.
# #Person1#과 다음 주가 할아버지 생일이라 #Person2#는 집에서 깜짝 파티를 열 계획입니다. #Person1#은 피자, 할머니가 케이크, 샐러드, 스카프, 모자 등을 준비할 예정입니다.
# ===================
#  Gian Luca Donatelli는 이탈리아 서비스 공급업체에서 프리랜서로 일하고 있으며, 로버트가 그를 소개해 줍니다.
# Gian Luca Donatelli는 이탈리아 서비스 공급업체에서 프리랜서로 일하고 있으며, 로버트가 그를 소개해 줍니다.
# ===================
#  #Person1#과 #Person2#는 노스캐롤라이나 산의 조용한 날에 대해 이야기합니다. Kathy는 산에서 내려와 주로 나무에 있으며, 새 배설물이 여기저기 있을 것이라고 #Person1#에게 말합니다.
# #Person1#과 #Person2#는 노스캐롤라이나 산의 조용한 날에 대해 이야기합니다. Kathy는 산에서 내려와 주로 나무에 있으며, 새 배설물이 여기저기 있을 것이라고 #Person1#에게 말합니다.
# ===================
#  #Person2#는 #Person1#의 도움으로 칠면조 샌드위치와 채소 소고기 수프, 그리고 다이어트 콜라를 주문합니다.
# #Person2#는 #Person1#의 도움으로 칠면조 샌드위치와 채소 소고기 수프, 그리고 다이어트 콜라를 주문합니다.
# ===================
#  James는 기차를 타기 위해 짐을 거의 다 챙겼고, David가 빌려준 재킷을 입고 시골에 가서 사진을 찍고 싶어 합니다. #Person1#은 James에게 쿠키는 할머니, 할아버지에게 드리기 위해 만든 것이라고 설명합니다.
# James는 기차를 타기 위해 짐을 거의 다 챙겼고, David가 빌려준 재킷을 입고 시골에 가서 사진을 찍고 싶어 합니다. #Person1#은 James에게 쿠키는 할머니, 할아버지에게 드리기 위해 만든 것이라고 설명합니다.
# ===================
#  테드는 장인어른과 장모님과 함께 친정에 머무르며 쉴 예정이다. #Person1#은 중국에 갈 예정이며, 테드는 가족과 나라를 둘러볼 계획이다.
# 테드는 장인어른과 장모님과 함께 친정에 머무르며 쉴 예정이다. #Person1#은 중국에 갈 예정이며, 테드는 가족과 나라를 둘러볼 계획이다.
# ===================
#  #Person1#과 #Person2#는 오늘 오후에 영화관에 가기로 했습니다. #Person1#의 이모 헬렌은 항상 영화관에 갑니다. 그들은 영화를 보고 맥도날드에 가기로 결정합니다.
# #Person1#과 #Person2#는 오늘 오후에 영화관에 가기로 했습니다. #Person1#의 이모 헬렌은 항상 영화관에 갑니다. 그들은 영화를 보고 맥도날드에 가기로 결정합니다.
# ===================
#  #Person2#는 어젯밤 도둑이 집에 침입하여 가구를 도난당했다고 경찰에 신고했습니다.
# #Person2#는 어젯밤 도둑이 집에 침입하여 가구를 도난당했다고 경찰에 신고했습니다.
# ===================
#  Jack은 Charlie에게 새로운 비디오 게임을 제안하고, C는 숙제를 먼저 끝내고 게임을 즐깁니다.
# Jack은 Charlie에게 새로운 비디오 게임을 제안하고, C는 숙제를 먼저 끝내고 게임을 즐깁니다.
# ===================
#  #Person2#는 #Person1#에게 시골 음악에 관심을 가지게 된 계기와 #Person1#이 라디오 방송국에서 일하게 된 계기를 설명합니다.
# #Person2#는 #Person1#에게 시골 음악에 관심을 가지게 된 계기와 #Person1#이 라디오 방송국에서 일하게 된 계기를 설명합니다.
# ===================
#  Alice는 #Person1#에게 세탁기 사용법을 설명합니다. #Person1#은 비누를 따로 넣어야 하며, 세탁 후 한 번도 세탁한 적이 없다고 말합니다. #Person2#는 처음에는 믿기 어렵다고 느낍니다.
# Alice는 #Person1#에게 세탁기 사용법을 설명합니다. #Person1#은 비누를 따로 넣어야 하며, 세탁 후 한 번도 세탁한 적이 없다고 말합니다. #Person2#는 처음에는 믿기 어렵다고 느낍니다.
# ===================
#  Steve는 Matthew에게 임대를 갱신하고 싶지 않다고 말하고, Mrs. Thou에게 아파트를 보여줄 수 있는지 물어보겠다고 한다.
# Steve는 Matthew에게 임대를 갱신하고 싶지 않다고 말하고, Mrs. Thou에게 아파트를 보여줄 수 있는지 물어보겠다고 한다.
# ===================
#  Betsy는 승진하여 친구들을 초대해 파티를 열 계획이며, 파티 인원은 150명 정도 될 것이라고 Frank에게 말합니다.
# Betsy는 승진하여 친구들을 초대해 파티를 열 계획이며, 파티 인원은 150명 정도 될 것이라고 Frank에게 말합니다.
# ===================

# %%
output  # 각 대화문에 대한 요약문이 출력됨을 확인할 수 있습니다.
